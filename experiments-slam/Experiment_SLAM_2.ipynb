# %% [markdown]
# <a href="https://colab.research.google.com/github/malcolmlett/robovac/blob/main/Experiment_SLAM_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Experiment: SLAM (v2)
# The first version was a bit of a mission to get to something working and it had so many side experiments. I now want to move forward with a clean baseline in order to make those improvements.
#
# Here I'll focus on improving the loss functions and possibly tweak the data representations if needed.
#
# I want to get to a point where the model trains as well as can be reasonable given the quality of the dataset.

# %%
import os
if os.path.isdir('repo'):
  # discard any local changes and update
  # !cd repo && git reset --hard HEAD
  # !cd repo && git fetch
else:
  # !git clone https://github.com/malcolmlett/robovac.git repo

# lock to revision
# !cd repo && git checkout e33eb2b
#!cd repo && git pull

import sys
sys.path.append('repo')

from general_utils import display_history
import lds
import slam
import slam_data
from importlib import reload
reload(lds)
reload(slam)
reload(slam_data)
# Out:
# Cloning into 'repo'...
# remote: Enumerating objects: 285, done.
# remote: Counting objects: 100% (155/155), done.
# remote: Compressing objects: 100% (97/97), done.
# remote: Total 285 (delta 94), reused 91 (delta 57), pack-reused 130 (from 1)
# Receiving objects: 100% (285/285), 18.27 MiB | 15.91 MiB/s, done.
# Resolving deltas: 100% (132/132), done.
# Already up to date.
# <module 'slam_data' from '/content/repo/slam_data.py'>

# %%
# !pip install -Uqq ipdb

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
import io
import os
import shutil
import tarfile
import cv2
import requests
import math
import ipdb
import tqdm
import time
from timeit import default_timer as timer
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 60.2 MB/s eta 0:00:00

# %% [markdown]
# ## Training data

# %%
# If generated data is available then load that to save time:
train_data = slam_data.load_dataset('repo/data/experimental-slam-training-data1.npz')
slam_data.validate_dataset(train_data)
# Out:
# Loaded:
#   input_maps:        (1000, 149, 149, 3)
#   lds_maps:          (1000, 149, 149)
#   ground_truth_maps: (1000, 149, 149, 3)
#   adlos:             (1000, 4)
# Dataset loaded from repo/data/experimental-slam-training-data1.npz
# Dataset tests passed (1000 entries verified)

# %%
# Alternatively, generate new data
#np.random.seed(0)
#train_data = generate_training_data(floorplan, 1000)
#train_data = slam_data.generate_training_data(floorplan, 1000, sample_types=[1])
#slam_data.validate_dataset(train_data)

# %%
# Uncomment to save dataset
#save_dataset(train_data, 'experimental-slam-training-data1-type1only.npz')

# %%
#slam_data.show_dataset(train_data, 5)

# %% [markdown]
# ## Model Training

# %%
# Custom loss functions
# (out-of-the-box the two outputs get losses calculated independently,
#  ultimately I'll be wanting to conditionally choose whether the map loss
#  is considered depending on how the network is being used.
#  The easiest way to do that will be to generate the dataset so that the ground_truth_map
#  is blank for those cases)

def adlo_loss(y_true, y_pred):
    """
    y_true: (B,4), scaled
    y_pred: (B,4), logits
    """
    y_true = tf.cast(y_true, tf.float32)

    # binary cross-entropy loss for accept
    accept_true = y_true[:, 0]
    accept_pred = y_pred[:, 0]
    accept_losses = tf.keras.losses.binary_crossentropy(accept_true, accept_pred, from_logits=True)

    # log-cosh loss for delta x, y, orientation
    dlo_true = y_true[:, 1:4]
    delta_x = tf.math.tanh(y_pred[:, 1]) * 0.5  # -0.5 .. +0.5
    delta_y = tf.math.tanh(y_pred[:, 2]) * 0.5  # -0.5 .. +0.5
    delta_angle = tf.math.tanh(y_pred[:, 3])    # -1.0 .. +1.0
    dlo_pred = tf.stack([delta_x, delta_y, delta_angle], axis=1)
    dlo_losses = tf.reduce_mean(tf.math.log(tf.cosh(y_pred - y_true)))

    return accept_losses + dlo_losses

def adlo_loss1(y_true, y_pred):
    """
    y_true: (B,4), scaled
    y_pred: (B,4), logits
    """
    y_true = tf.cast(y_true, tf.float32)
    # scale logits to correct ranges
    accept_true = y_true[:, 0]
    #accept_pred = tf.nn.sigmoid(y_pred[:, 0])

    #accept_pred = tf.nn.sigmoid(y_pred[:, 0])
    #losses = tf.keras.losses.MSE(accept_true, accept_pred)
    #losses = tf.keras.losses.binary_crossentropy(accept_true, accept_pred, from_logits=False)
    print(f"y_true: {y_true.shape}, y_pred: {y_pred.shape}")

    #accept_pred = y_pred[:, 0]
    accept_pred = tf.gather(y_pred, 0, axis=1)

    losses = tf.keras.losses.binary_crossentropy(accept_true, accept_pred, from_logits=True)
    #print(f"accept_true: {accept_true.shape}, accept_pred: {accept_pred.shape}, losses: {losses.shape}")
    #print(f"accept_true ({accept_true.dtype}): {accept_true[0:10]}")
    #print(f"accept_pred ({accept_pred.dtype}): {accept_pred[0:10]}")
    #print(f"accept_pred: {tf.nn.sigmoid(accept_pred[0:10])}")
    #print(f"losses:     ({losses.dtype}) {losses}")

    #lg = tf.math.log(tf.nn.sigmoid(accept_pred))
    #bce = -tf.multiply(accept_true, tf.math.log(tf.nn.sigmoid(accept_pred))) - tf.multiply(1-accept_true, tf.math.log(1-tf.nn.sigmoid(accept_pred)))
    #print(f"log:         {lg[0:10]}")
    #print(f"derivation:  {tf.reduce_mean(bce)} <- {bce[0:10]}")

    return tf.reduce_mean(losses)

def accept_accuracy(y_true, y_pred):
    accept_true = tf.cast(y_true[:, 0], tf.float32)
    accept_pred = tf.cast(tf.round(tf.nn.sigmoid(y_pred[:, 0])), tf.float32)
    matches = tf.equal(accept_true, accept_pred)
    return tf.reduce_mean(tf.cast(matches, tf.float32))

def loc_error(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    loc_true = y_true[:, 1:3]
    loc_pred = tf.math.tanh(y_pred[:, 1:3]) * 0.5  # -0.5 .. +0.5
    losses = tf.math.sqrt(tf.keras.losses.MSE(loc_true, loc_pred))
    return tf.reduce_mean(losses)

def orientation_error(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    angle_true = y_true[:, 3]
    angle_pred = tf.math.tanh(y_pred[:, 3])  # -1.0 .. +1.0
    losses = tf.math.sqrt(tf.keras.losses.MSE(angle_true, angle_pred))
    return tf.reduce_mean(losses)

reload(slam)
reload(slam_data)
one = next(iter(train_data))
map_shape = one[0][0].shape
print(f"map_shape: {map_shape}")
np.random.seed(42)
tf.random.set_seed(42)

model = slam.slam_model(map_shape, conv_filters=32, adlo_units=256)
model.compile(optimizer='adam',
              #run_eagerly=True,
              loss={
                  'map_output': tf.keras.losses.CategoricalCrossentropy(from_logits=True),
                  'adlo_output': adlo_loss
              },
              metrics={
                  'map_output': [tf.keras.metrics.CategoricalCrossentropy(from_logits=True, name='map_loss'), 'accuracy'],
                  'adlo_output': [adlo_loss, accept_accuracy, loc_error, orientation_error]
              })

epochs = 200
batch_size = 32
model_train_data = train_data.shuffle(buffer_size=len(train_data)).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

start = timer()
model_history = model.fit(model_train_data, epochs=epochs)
duration = (timer() - start)
print(f"Epochs: {epochs}, duration: {duration} sec")
display_history(model_history)
slam_data.show_predictions(model, train_data, 5, show_classes='pred')
# Out:
# map_shape: (149, 149, 3)
# Added final cropping layer: w=11, h=11
# Prepared SLAM model
#   Map shape:        (149, 149, 3) + padding (11, 11, 0)
#   Skip-connections: concat
#   Output scaling:   logits
#   Inputs:           [<KerasTensor shape=(None, 149, 149, 3), dtype=float32, sparse=None, name=map_input>, <KerasTensor shape=(None, 149, 149), dtype=float32, sparse=None, name=lds_input>]
#   Outputs:          [<KerasTensor shape=(None, 149, 149, 3), dtype=float32, sparse=False, name=keras_tensor_51>, <KerasTensor shape=(None, 4), dtype=float32, sparse=False, name=keras_tensor_56>]
# Epoch 1/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 85s 1s/step - adlo_output_accept_accuracy: 0.6321 - adlo_output_adlo_loss: 1.3113 - adlo_output_loc_error: 0.1636 - adlo_output_orientation_error: 0.3101 - loss: 2.0668 - map_output_accuracy: 0.6707 - map_output_map_loss: 0.7550
# Epoch 2/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 368ms/step - adlo_output_accept_accuracy: 0.7431 - adlo_output_adlo_loss: 0.6133 - adlo_output_loc_error: 0.0835 - adlo_output_orientation_error: 0.2718 - loss: 1.2140 - map_output_accuracy: 0.7498 - map_output_map_loss: 0.6007
# Epoch 3/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 370ms/step - adlo_output_accept_accuracy: 0.7342 - adlo_output_adlo_loss: 0.6031 - adlo_output_loc_error: 0.0782 - adlo_output_orientation_error: 0.2725 - loss: 1.1775 - map_output_accuracy: 0.7558 - map_output_map_loss: 0.5743
# Epoch 4/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 374ms/step - adlo_output_accept_accuracy: 0.7138 - adlo_output_adlo_loss: 0.6030 - adlo_output_loc_error: 0.0734 - adlo_output_orientation_error: 0.2610 - loss: 1.1453 - map_output_accuracy: 0.7824 - map_output_map_loss: 0.5422
# Epoch 5/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 376ms/step - adlo_output_accept_accuracy: 0.7181 - adlo_output_adlo_loss: 0.5902 - adlo_output_loc_error: 0.0701 - adlo_output_orientation_error: 0.2541 - loss: 1.1146 - map_output_accuracy: 0.7845 - map_output_map_loss: 0.5241
# Epoch 6/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 376ms/step - adlo_output_accept_accuracy: 0.7449 - adlo_output_adlo_loss: 0.5715 - adlo_output_loc_error: 0.0863 - adlo_output_orientation_error: 0.2793 - loss: 1.0697 - map_output_accuracy: 0.8038 - map_output_map_loss: 0.4979
# Epoch 7/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 378ms/step - adlo_output_accept_accuracy: 0.7240 - adlo_output_adlo_loss: 0.5641 - adlo_output_loc_error: 0.0724 - adlo_output_orientation_error: 0.2609 - loss: 1.0752 - map_output_accuracy: 0.7870 - map_output_map_loss: 0.5109
# Epoch 8/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 377ms/step - adlo_output_accept_accuracy: 0.7708 - adlo_output_adlo_loss: 0.5342 - adlo_output_loc_error: 0.0746 - adlo_output_orientation_error: 0.2563 - loss: 1.0524 - map_output_accuracy: 0.7848 - map_output_map_loss: 0.5180
# Epoch 9/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 379ms/step - adlo_output_accept_accuracy: 0.7786 - adlo_output_adlo_loss: 0.5243 - adlo_output_loc_error: 0.0789 - adlo_output_orientation_error: 0.2638 - loss: 1.0128 - map_output_accuracy: 0.8050 - map_output_map_loss: 0.4885
# Epoch 10/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 377ms/step - adlo_output_accept_accuracy: 0.7947 - adlo_output_adlo_loss: 0.5013 - adlo_output_loc_error: 0.0789 - adlo_output_orientation_error: 0.2791 - loss: 0.9968 - map_output_accuracy: 0.7965 - map_output_map_loss: 0.4955
# Epoch 11/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 380ms/step - adlo_output_accept_accuracy: 0.8192 - adlo_output_adlo_loss: 0.4937 - adlo_output_loc_error: 0.0766 - adlo_output_orientation_error: 0.2504 - loss: 0.9963 - map_output_accuracy: 0.7928 - map_output_map_loss: 0.5024
# Epoch 12/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 380ms/step - adlo_output_accept_accuracy: 0.8596 - adlo_output_adlo_loss: 0.4419 - adlo_output_loc_error: 0.0809 - adlo_output_orientation_error: 0.2552 - loss: 0.9160 - map_output_accuracy: 0.8080 - map_output_map_loss: 0.4743
# Epoch 13/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 382ms/step - adlo_output_accept_accuracy: 0.9124 - adlo_output_adlo_loss: 0.3946 - adlo_output_loc_error: 0.0725 - adlo_output_orientation_error: 0.2463 - loss: 0.8623 - map_output_accuracy: 0.8096 - map_output_map_loss: 0.4681
# Epoch 14/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 383ms/step - adlo_output_accept_accuracy: 0.9139 - adlo_output_adlo_loss: 0.3939 - adlo_output_loc_error: 0.0715 - adlo_output_orientation_error: 0.2498 - loss: 0.8808 - map_output_accuracy: 0.7940 - map_output_map_loss: 0.4871
# Epoch 15/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 381ms/step - adlo_output_accept_accuracy: 0.9522 - adlo_output_adlo_loss: 0.3595 - adlo_output_loc_error: 0.0781 - adlo_output_orientation_error: 0.2630 - loss: 0.8289 - map_output_accuracy: 0.7998 - map_output_map_loss: 0.4693
# Epoch 16/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 381ms/step - adlo_output_accept_accuracy: 0.9698 - adlo_output_adlo_loss: 0.3337 - adlo_output_loc_error: 0.0740 - adlo_output_orientation_error: 0.2395 - loss: 0.7951 - map_output_accuracy: 0.8079 - map_output_map_loss: 0.4615
# Epoch 17/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 379ms/step - adlo_output_accept_accuracy: 0.9585 - adlo_output_adlo_loss: 0.3448 - adlo_output_loc_error: 0.0757 - adlo_output_orientation_error: 0.2349 - loss: 0.8121 - map_output_accuracy: 0.8034 - map_output_map_loss: 0.4672
# Epoch 18/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 382ms/step - adlo_output_accept_accuracy: 0.9655 - adlo_output_adlo_loss: 0.3239 - adlo_output_loc_error: 0.0732 - adlo_output_orientation_error: 0.2477 - loss: 0.7666 - map_output_accuracy: 0.8162 - map_output_map_loss: 0.4426
# Epoch 19/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 379ms/step - adlo_output_accept_accuracy: 0.9933 - adlo_output_adlo_loss: 0.3071 - adlo_output_loc_error: 0.0725 - adlo_output_orientation_error: 0.2263 - loss: 0.7556 - map_output_accuracy: 0.8084 - map_output_map_loss: 0.4485
# Epoch 20/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 382ms/step - adlo_output_accept_accuracy: 0.9933 - adlo_output_adlo_loss: 0.3043 - adlo_output_loc_error: 0.0733 - adlo_output_orientation_error: 0.2291 - loss: 0.7467 - map_output_accuracy: 0.8106 - map_output_map_loss: 0.4425
# Epoch 21/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 386ms/step - adlo_output_accept_accuracy: 0.9993 - adlo_output_adlo_loss: 0.2965 - adlo_output_loc_error: 0.0713 - adlo_output_orientation_error: 0.2188 - loss: 0.7192 - map_output_accuracy: 0.8203 - map_output_map_loss: 0.4226
# Epoch 22/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 393ms/step - adlo_output_accept_accuracy: 0.9995 - adlo_output_adlo_loss: 0.2890 - adlo_output_loc_error: 0.0746 - adlo_output_orientation_error: 0.2188 - loss: 0.6974 - map_output_accuracy: 0.8296 - map_output_map_loss: 0.4083
# Epoch 23/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 400ms/step - adlo_output_accept_accuracy: 0.9975 - adlo_output_adlo_loss: 0.2922 - adlo_output_loc_error: 0.0696 - adlo_output_orientation_error: 0.1980 - loss: 0.6919 - map_output_accuracy: 0.8318 - map_output_map_loss: 0.3996
# Epoch 24/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 398ms/step - adlo_output_accept_accuracy: 0.9998 - adlo_output_adlo_loss: 0.2857 - adlo_output_loc_error: 0.0684 - adlo_output_orientation_error: 0.2082 - loss: 0.6640 - map_output_accuracy: 0.8389 - map_output_map_loss: 0.3783
# Epoch 25/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 399ms/step - adlo_output_accept_accuracy: 0.9995 - adlo_output_adlo_loss: 0.2895 - adlo_output_loc_error: 0.0732 - adlo_output_orientation_error: 0.1916 - loss: 0.6467 - map_output_accuracy: 0.8489 - map_output_map_loss: 0.3572
# Epoch 26/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 397ms/step - adlo_output_accept_accuracy: 0.9927 - adlo_output_adlo_loss: 0.2898 - adlo_output_loc_error: 0.0715 - adlo_output_orientation_error: 0.2021 - loss: 0.5890 - map_output_accuracy: 0.8755 - map_output_map_loss: 0.2993
# Epoch 27/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 392ms/step - adlo_output_accept_accuracy: 0.9913 - adlo_output_adlo_loss: 0.2978 - adlo_output_loc_error: 0.0719 - adlo_output_orientation_error: 0.2117 - loss: 0.6415 - map_output_accuracy: 0.8552 - map_output_map_loss: 0.3438
# Epoch 28/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 398ms/step - adlo_output_accept_accuracy: 0.9613 - adlo_output_adlo_loss: 0.3308 - adlo_output_loc_error: 0.0674 - adlo_output_orientation_error: 0.2073 - loss: 0.7070 - map_output_accuracy: 0.8437 - map_output_map_loss: 0.3762
# Epoch 29/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 402ms/step - adlo_output_accept_accuracy: 0.9637 - adlo_output_adlo_loss: 0.3440 - adlo_output_loc_error: 0.0777 - adlo_output_orientation_error: 0.2313 - loss: 0.6978 - map_output_accuracy: 0.8475 - map_output_map_loss: 0.3538
# Epoch 30/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 403ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2916 - adlo_output_loc_error: 0.0702 - adlo_output_orientation_error: 0.2146 - loss: 0.6070 - map_output_accuracy: 0.8705 - map_output_map_loss: 0.3154
# Epoch 31/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 393ms/step - adlo_output_accept_accuracy: 0.9985 - adlo_output_adlo_loss: 0.2867 - adlo_output_loc_error: 0.0660 - adlo_output_orientation_error: 0.1932 - loss: 0.5759 - map_output_accuracy: 0.8795 - map_output_map_loss: 0.2892
# Epoch 32/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 393ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2822 - adlo_output_loc_error: 0.0700 - adlo_output_orientation_error: 0.1915 - loss: 0.5285 - map_output_accuracy: 0.9033 - map_output_map_loss: 0.2463
# Epoch 33/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 399ms/step - adlo_output_accept_accuracy: 0.9971 - adlo_output_adlo_loss: 0.2838 - adlo_output_loc_error: 0.0706 - adlo_output_orientation_error: 0.1759 - loss: 0.5236 - map_output_accuracy: 0.9038 - map_output_map_loss: 0.2398
# Epoch 34/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 401ms/step - adlo_output_accept_accuracy: 0.9994 - adlo_output_adlo_loss: 0.2851 - adlo_output_loc_error: 0.0689 - adlo_output_orientation_error: 0.1841 - loss: 0.5101 - map_output_accuracy: 0.9114 - map_output_map_loss: 0.2250
# Epoch 35/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 399ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2877 - adlo_output_loc_error: 0.0706 - adlo_output_orientation_error: 0.1776 - loss: 0.5026 - map_output_accuracy: 0.9171 - map_output_map_loss: 0.2149
# Epoch 36/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 397ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2787 - adlo_output_loc_error: 0.0661 - adlo_output_orientation_error: 0.1624 - loss: 0.4550 - map_output_accuracy: 0.9339 - map_output_map_loss: 0.1764
# Epoch 37/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 391ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2783 - adlo_output_loc_error: 0.0659 - adlo_output_orientation_error: 0.1545 - loss: 0.4492 - map_output_accuracy: 0.9362 - map_output_map_loss: 0.1710
# Epoch 38/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 395ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2800 - adlo_output_loc_error: 0.0645 - adlo_output_orientation_error: 0.1326 - loss: 0.4463 - map_output_accuracy: 0.9396 - map_output_map_loss: 0.1663
# Epoch 39/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 399ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2809 - adlo_output_loc_error: 0.0630 - adlo_output_orientation_error: 0.1244 - loss: 0.4263 - map_output_accuracy: 0.9475 - map_output_map_loss: 0.1454
# Epoch 40/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 398ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2779 - adlo_output_loc_error: 0.0639 - adlo_output_orientation_error: 0.1288 - loss: 0.4175 - map_output_accuracy: 0.9498 - map_output_map_loss: 0.1397
# Epoch 41/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 397ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2786 - adlo_output_loc_error: 0.0625 - adlo_output_orientation_error: 0.1280 - loss: 0.4089 - map_output_accuracy: 0.9537 - map_output_map_loss: 0.1303
# Epoch 42/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 395ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2767 - adlo_output_loc_error: 0.0646 - adlo_output_orientation_error: 0.1230 - loss: 0.4178 - map_output_accuracy: 0.9491 - map_output_map_loss: 0.1411
# Epoch 43/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 393ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2747 - adlo_output_loc_error: 0.0649 - adlo_output_orientation_error: 0.1142 - loss: 0.4066 - map_output_accuracy: 0.9534 - map_output_map_loss: 0.1319
# Epoch 44/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 392ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2762 - adlo_output_loc_error: 0.0609 - adlo_output_orientation_error: 0.1171 - loss: 0.4099 - map_output_accuracy: 0.9526 - map_output_map_loss: 0.1337
# Epoch 45/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 390ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2795 - adlo_output_loc_error: 0.0554 - adlo_output_orientation_error: 0.1017 - loss: 0.4095 - map_output_accuracy: 0.9548 - map_output_map_loss: 0.1300
# Epoch 46/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 387ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2768 - adlo_output_loc_error: 0.0606 - adlo_output_orientation_error: 0.1127 - loss: 0.4057 - map_output_accuracy: 0.9546 - map_output_map_loss: 0.1288
# Epoch 47/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 385ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2774 - adlo_output_loc_error: 0.0647 - adlo_output_orientation_error: 0.1094 - loss: 0.4096 - map_output_accuracy: 0.9539 - map_output_map_loss: 0.1322
# Epoch 48/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 383ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2784 - adlo_output_loc_error: 0.0568 - adlo_output_orientation_error: 0.1058 - loss: 0.4021 - map_output_accuracy: 0.9568 - map_output_map_loss: 0.1237
# Epoch 49/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 386ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2775 - adlo_output_loc_error: 0.0583 - adlo_output_orientation_error: 0.0931 - loss: 0.3937 - map_output_accuracy: 0.9598 - map_output_map_loss: 0.1161
# Epoch 50/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 387ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2816 - adlo_output_loc_error: 0.0597 - adlo_output_orientation_error: 0.0980 - loss: 0.4053 - map_output_accuracy: 0.9570 - map_output_map_loss: 0.1237
# Epoch 51/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 388ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2760 - adlo_output_loc_error: 0.0614 - adlo_output_orientation_error: 0.1120 - loss: 0.3897 - map_output_accuracy: 0.9604 - map_output_map_loss: 0.1137
# Epoch 52/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 390ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2784 - adlo_output_loc_error: 0.0521 - adlo_output_orientation_error: 0.0938 - loss: 0.3946 - map_output_accuracy: 0.9597 - map_output_map_loss: 0.1161
# Epoch 53/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 386ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2796 - adlo_output_loc_error: 0.0546 - adlo_output_orientation_error: 0.0897 - loss: 0.3847 - map_output_accuracy: 0.9632 - map_output_map_loss: 0.1051
# Epoch 54/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 388ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2786 - adlo_output_loc_error: 0.0539 - adlo_output_orientation_error: 0.0865 - loss: 0.3865 - map_output_accuracy: 0.9623 - map_output_map_loss: 0.1079
# Epoch 55/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 385ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2778 - adlo_output_loc_error: 0.0539 - adlo_output_orientation_error: 0.0966 - loss: 0.3812 - map_output_accuracy: 0.9639 - map_output_map_loss: 0.1033
# Epoch 56/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 388ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2769 - adlo_output_loc_error: 0.0502 - adlo_output_orientation_error: 0.0787 - loss: 0.3768 - map_output_accuracy: 0.9651 - map_output_map_loss: 0.0999
# Epoch 57/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 385ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2756 - adlo_output_loc_error: 0.0527 - adlo_output_orientation_error: 0.0789 - loss: 0.3784 - map_output_accuracy: 0.9639 - map_output_map_loss: 0.1027
# Epoch 58/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 387ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2772 - adlo_output_loc_error: 0.0463 - adlo_output_orientation_error: 0.0804 - loss: 0.3731 - map_output_accuracy: 0.9660 - map_output_map_loss: 0.0960
# Epoch 59/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 387ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2760 - adlo_output_loc_error: 0.0537 - adlo_output_orientation_error: 0.0805 - loss: 0.3617 - map_output_accuracy: 0.9696 - map_output_map_loss: 0.0858
# Epoch 60/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 388ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2779 - adlo_output_loc_error: 0.0506 - adlo_output_orientation_error: 0.0790 - loss: 0.3651 - map_output_accuracy: 0.9690 - map_output_map_loss: 0.0872
# Epoch 61/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 387ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2766 - adlo_output_loc_error: 0.0462 - adlo_output_orientation_error: 0.0706 - loss: 0.3612 - map_output_accuracy: 0.9697 - map_output_map_loss: 0.0847
# Epoch 62/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 385ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2786 - adlo_output_loc_error: 0.0454 - adlo_output_orientation_error: 0.0670 - loss: 0.3642 - map_output_accuracy: 0.9692 - map_output_map_loss: 0.0856
# Epoch 63/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 386ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2775 - adlo_output_loc_error: 0.0466 - adlo_output_orientation_error: 0.0702 - loss: 0.3607 - map_output_accuracy: 0.9702 - map_output_map_loss: 0.0832
# Epoch 64/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 383ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2765 - adlo_output_loc_error: 0.0446 - adlo_output_orientation_error: 0.0727 - loss: 0.3585 - map_output_accuracy: 0.9707 - map_output_map_loss: 0.0820
# Epoch 65/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 386ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2756 - adlo_output_loc_error: 0.0442 - adlo_output_orientation_error: 0.0678 - loss: 0.3508 - map_output_accuracy: 0.9733 - map_output_map_loss: 0.0752
# Epoch 66/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 388ms/step - adlo_output_accept_accuracy: 0.9996 - adlo_output_adlo_loss: 0.2790 - adlo_output_loc_error: 0.0476 - adlo_output_orientation_error: 0.0888 - loss: 0.3824 - map_output_accuracy: 0.9642 - map_output_map_loss: 0.1034
# Epoch 67/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 388ms/step - adlo_output_accept_accuracy: 0.9329 - adlo_output_adlo_loss: 0.3742 - adlo_output_loc_error: 0.0720 - adlo_output_orientation_error: 0.2041 - loss: 0.8025 - map_output_accuracy: 0.8475 - map_output_map_loss: 0.4281
# Epoch 68/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 384ms/step - adlo_output_accept_accuracy: 0.8637 - adlo_output_adlo_loss: 0.4603 - adlo_output_loc_error: 0.0894 - adlo_output_orientation_error: 0.2817 - loss: 0.9339 - map_output_accuracy: 0.8108 - map_output_map_loss: 0.4736
# Epoch 69/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 384ms/step - adlo_output_accept_accuracy: 0.9594 - adlo_output_adlo_loss: 0.3447 - adlo_output_loc_error: 0.0782 - adlo_output_orientation_error: 0.2540 - loss: 0.6789 - map_output_accuracy: 0.8666 - map_output_map_loss: 0.3342
# Epoch 70/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 386ms/step - adlo_output_accept_accuracy: 0.9840 - adlo_output_adlo_loss: 0.3109 - adlo_output_loc_error: 0.0800 - adlo_output_orientation_error: 0.2375 - loss: 0.5762 - map_output_accuracy: 0.8988 - map_output_map_loss: 0.2653
# Epoch 71/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 387ms/step - adlo_output_accept_accuracy: 0.9978 - adlo_output_adlo_loss: 0.2881 - adlo_output_loc_error: 0.0717 - adlo_output_orientation_error: 0.1948 - loss: 0.4951 - map_output_accuracy: 0.9227 - map_output_map_loss: 0.2069
# Epoch 72/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 385ms/step - adlo_output_accept_accuracy: 0.9961 - adlo_output_adlo_loss: 0.2864 - adlo_output_loc_error: 0.0669 - adlo_output_orientation_error: 0.1987 - loss: 0.4657 - map_output_accuracy: 0.9350 - map_output_map_loss: 0.1794
# Epoch 73/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 387ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2796 - adlo_output_loc_error: 0.0632 - adlo_output_orientation_error: 0.1649 - loss: 0.4149 - map_output_accuracy: 0.9510 - map_output_map_loss: 0.1353
# Epoch 74/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 388ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2759 - adlo_output_loc_error: 0.0602 - adlo_output_orientation_error: 0.1257 - loss: 0.4000 - map_output_accuracy: 0.9556 - map_output_map_loss: 0.1240
# Epoch 75/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 385ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2784 - adlo_output_loc_error: 0.0594 - adlo_output_orientation_error: 0.1221 - loss: 0.3808 - map_output_accuracy: 0.9637 - map_output_map_loss: 0.1024
# Epoch 76/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 388ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2777 - adlo_output_loc_error: 0.0596 - adlo_output_orientation_error: 0.1126 - loss: 0.3722 - map_output_accuracy: 0.9663 - map_output_map_loss: 0.0944
# Epoch 77/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 388ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2769 - adlo_output_loc_error: 0.0595 - adlo_output_orientation_error: 0.1046 - loss: 0.3658 - map_output_accuracy: 0.9681 - map_output_map_loss: 0.0888
# Epoch 78/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 385ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2758 - adlo_output_loc_error: 0.0547 - adlo_output_orientation_error: 0.0911 - loss: 0.3611 - map_output_accuracy: 0.9695 - map_output_map_loss: 0.0853
# Epoch 79/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 390ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2795 - adlo_output_loc_error: 0.0516 - adlo_output_orientation_error: 0.0835 - loss: 0.3628 - map_output_accuracy: 0.9705 - map_output_map_loss: 0.0833
# Epoch 80/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 397ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2802 - adlo_output_loc_error: 0.0509 - adlo_output_orientation_error: 0.0820 - loss: 0.3612 - map_output_accuracy: 0.9712 - map_output_map_loss: 0.0810
# Epoch 81/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 401ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2755 - adlo_output_loc_error: 0.0483 - adlo_output_orientation_error: 0.0823 - loss: 0.3520 - map_output_accuracy: 0.9727 - map_output_map_loss: 0.0765
# Epoch 82/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 396ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2722 - adlo_output_loc_error: 0.0496 - adlo_output_orientation_error: 0.0807 - loss: 0.3482 - map_output_accuracy: 0.9728 - map_output_map_loss: 0.0760
# Epoch 83/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 398ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2794 - adlo_output_loc_error: 0.0494 - adlo_output_orientation_error: 0.0793 - loss: 0.3607 - map_output_accuracy: 0.9714 - map_output_map_loss: 0.0812
# Epoch 84/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 397ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2705 - adlo_output_loc_error: 0.0516 - adlo_output_orientation_error: 0.0807 - loss: 0.3429 - map_output_accuracy: 0.9744 - map_output_map_loss: 0.0724
# Epoch 85/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 397ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2747 - adlo_output_loc_error: 0.0445 - adlo_output_orientation_error: 0.0772 - loss: 0.3465 - map_output_accuracy: 0.9744 - map_output_map_loss: 0.0718
# Epoch 86/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 397ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2775 - adlo_output_loc_error: 0.0458 - adlo_output_orientation_error: 0.0705 - loss: 0.3485 - map_output_accuracy: 0.9746 - map_output_map_loss: 0.0710
# Epoch 87/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 394ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2799 - adlo_output_loc_error: 0.0412 - adlo_output_orientation_error: 0.0701 - loss: 0.3511 - map_output_accuracy: 0.9745 - map_output_map_loss: 0.0712
# Epoch 88/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 399ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2738 - adlo_output_loc_error: 0.0459 - adlo_output_orientation_error: 0.0693 - loss: 0.3408 - map_output_accuracy: 0.9760 - map_output_map_loss: 0.0670
# Epoch 89/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 400ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2720 - adlo_output_loc_error: 0.0465 - adlo_output_orientation_error: 0.0714 - loss: 0.3341 - map_output_accuracy: 0.9779 - map_output_map_loss: 0.0621
# Epoch 90/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 398ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2777 - adlo_output_loc_error: 0.0466 - adlo_output_orientation_error: 0.0729 - loss: 0.3386 - map_output_accuracy: 0.9782 - map_output_map_loss: 0.0609
# Epoch 91/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 392ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2790 - adlo_output_loc_error: 0.0409 - adlo_output_orientation_error: 0.0606 - loss: 0.3460 - map_output_accuracy: 0.9760 - map_output_map_loss: 0.0670
# Epoch 92/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 398ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2739 - adlo_output_loc_error: 0.0425 - adlo_output_orientation_error: 0.0687 - loss: 0.3351 - map_output_accuracy: 0.9781 - map_output_map_loss: 0.0611
# Epoch 93/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 401ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2727 - adlo_output_loc_error: 0.0460 - adlo_output_orientation_error: 0.0688 - loss: 0.3313 - map_output_accuracy: 0.9789 - map_output_map_loss: 0.0587
# Epoch 94/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 396ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2749 - adlo_output_loc_error: 0.0423 - adlo_output_orientation_error: 0.0647 - loss: 0.3325 - map_output_accuracy: 0.9793 - map_output_map_loss: 0.0575
# Epoch 95/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 396ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2795 - adlo_output_loc_error: 0.0408 - adlo_output_orientation_error: 0.0670 - loss: 0.3381 - map_output_accuracy: 0.9789 - map_output_map_loss: 0.0586
# Epoch 96/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 395ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2717 - adlo_output_loc_error: 0.0463 - adlo_output_orientation_error: 0.0712 - loss: 0.3253 - map_output_accuracy: 0.9807 - map_output_map_loss: 0.0536
# Epoch 97/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 390ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2774 - adlo_output_loc_error: 0.0429 - adlo_output_orientation_error: 0.0611 - loss: 0.3330 - map_output_accuracy: 0.9800 - map_output_map_loss: 0.0556
# Epoch 98/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 390ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2763 - adlo_output_loc_error: 0.0424 - adlo_output_orientation_error: 0.0670 - loss: 0.3289 - map_output_accuracy: 0.9811 - map_output_map_loss: 0.0526
# Epoch 99/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 392ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2780 - adlo_output_loc_error: 0.0443 - adlo_output_orientation_error: 0.0640 - loss: 0.3353 - map_output_accuracy: 0.9796 - map_output_map_loss: 0.0574
# Epoch 100/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 393ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2741 - adlo_output_loc_error: 0.0441 - adlo_output_orientation_error: 0.0652 - loss: 0.3388 - map_output_accuracy: 0.9780 - map_output_map_loss: 0.0646
# Epoch 101/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 394ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2758 - adlo_output_loc_error: 0.0420 - adlo_output_orientation_error: 0.0698 - loss: 0.3418 - map_output_accuracy: 0.9767 - map_output_map_loss: 0.0660
# Epoch 102/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 389ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2742 - adlo_output_loc_error: 0.0450 - adlo_output_orientation_error: 0.0745 - loss: 0.3375 - map_output_accuracy: 0.9778 - map_output_map_loss: 0.0632
# Epoch 103/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 390ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2757 - adlo_output_loc_error: 0.0447 - adlo_output_orientation_error: 0.0664 - loss: 0.3327 - map_output_accuracy: 0.9796 - map_output_map_loss: 0.0570
# Epoch 104/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 387ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2774 - adlo_output_loc_error: 0.0438 - adlo_output_orientation_error: 0.0672 - loss: 0.3374 - map_output_accuracy: 0.9786 - map_output_map_loss: 0.0600
# Epoch 105/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 389ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2715 - adlo_output_loc_error: 0.0454 - adlo_output_orientation_error: 0.0683 - loss: 0.3334 - map_output_accuracy: 0.9783 - map_output_map_loss: 0.0620
# Epoch 106/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 390ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2757 - adlo_output_loc_error: 0.0418 - adlo_output_orientation_error: 0.0743 - loss: 0.3331 - map_output_accuracy: 0.9795 - map_output_map_loss: 0.0575
# Epoch 107/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 387ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2776 - adlo_output_loc_error: 0.0415 - adlo_output_orientation_error: 0.0635 - loss: 0.3376 - map_output_accuracy: 0.9786 - map_output_map_loss: 0.0600
# Epoch 108/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 385ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2715 - adlo_output_loc_error: 0.0437 - adlo_output_orientation_error: 0.0719 - loss: 0.3232 - map_output_accuracy: 0.9814 - map_output_map_loss: 0.0518
# Epoch 109/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 389ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2749 - adlo_output_loc_error: 0.0445 - adlo_output_orientation_error: 0.0630 - loss: 0.3240 - map_output_accuracy: 0.9823 - map_output_map_loss: 0.0491
# Epoch 110/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 395ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2739 - adlo_output_loc_error: 0.0437 - adlo_output_orientation_error: 0.0638 - loss: 0.3214 - map_output_accuracy: 0.9829 - map_output_map_loss: 0.0474
# Epoch 111/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 401ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2731 - adlo_output_loc_error: 0.0425 - adlo_output_orientation_error: 0.0652 - loss: 0.3239 - map_output_accuracy: 0.9820 - map_output_map_loss: 0.0508
# Epoch 112/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 398ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2766 - adlo_output_loc_error: 0.0437 - adlo_output_orientation_error: 0.0704 - loss: 0.3284 - map_output_accuracy: 0.9816 - map_output_map_loss: 0.0518
# Epoch 113/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 396ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2740 - adlo_output_loc_error: 0.0462 - adlo_output_orientation_error: 0.0668 - loss: 0.3204 - map_output_accuracy: 0.9834 - map_output_map_loss: 0.0465
# Epoch 114/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 400ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2730 - adlo_output_loc_error: 0.0409 - adlo_output_orientation_error: 0.0594 - loss: 0.3232 - map_output_accuracy: 0.9821 - map_output_map_loss: 0.0502
# Epoch 115/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 401ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2791 - adlo_output_loc_error: 0.0377 - adlo_output_orientation_error: 0.0654 - loss: 0.3270 - map_output_accuracy: 0.9828 - map_output_map_loss: 0.0478
# Epoch 116/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 398ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2725 - adlo_output_loc_error: 0.0431 - adlo_output_orientation_error: 0.0659 - loss: 0.3143 - map_output_accuracy: 0.9850 - map_output_map_loss: 0.0419
# Epoch 117/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 393ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2783 - adlo_output_loc_error: 0.0383 - adlo_output_orientation_error: 0.0573 - loss: 0.3234 - map_output_accuracy: 0.9837 - map_output_map_loss: 0.0451
# Epoch 118/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 398ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2748 - adlo_output_loc_error: 0.0399 - adlo_output_orientation_error: 0.0582 - loss: 0.3194 - map_output_accuracy: 0.9840 - map_output_map_loss: 0.0446
# Epoch 119/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 397ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2754 - adlo_output_loc_error: 0.0399 - adlo_output_orientation_error: 0.0559 - loss: 0.3210 - map_output_accuracy: 0.9835 - map_output_map_loss: 0.0456
# Epoch 120/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 399ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2732 - adlo_output_loc_error: 0.0419 - adlo_output_orientation_error: 0.0589 - loss: 0.3171 - map_output_accuracy: 0.9842 - map_output_map_loss: 0.0440
# Epoch 121/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 399ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2724 - adlo_output_loc_error: 0.0405 - adlo_output_orientation_error: 0.0610 - loss: 0.3164 - map_output_accuracy: 0.9842 - map_output_map_loss: 0.0439
# Epoch 122/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 394ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2714 - adlo_output_loc_error: 0.0385 - adlo_output_orientation_error: 0.0602 - loss: 0.3132 - map_output_accuracy: 0.9849 - map_output_map_loss: 0.0418
# Epoch 123/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 399ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2730 - adlo_output_loc_error: 0.0424 - adlo_output_orientation_error: 0.0605 - loss: 0.3151 - map_output_accuracy: 0.9848 - map_output_map_loss: 0.0421
# Epoch 124/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 402ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2786 - adlo_output_loc_error: 0.0410 - adlo_output_orientation_error: 0.0574 - loss: 0.3186 - map_output_accuracy: 0.9857 - map_output_map_loss: 0.0399
# Epoch 125/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 398ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2768 - adlo_output_loc_error: 0.0384 - adlo_output_orientation_error: 0.0554 - loss: 0.3167 - map_output_accuracy: 0.9856 - map_output_map_loss: 0.0398
# Epoch 126/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 393ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2742 - adlo_output_loc_error: 0.0396 - adlo_output_orientation_error: 0.0620 - loss: 0.3137 - map_output_accuracy: 0.9858 - map_output_map_loss: 0.0395
# Epoch 127/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 395ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2753 - adlo_output_loc_error: 0.0389 - adlo_output_orientation_error: 0.0601 - loss: 0.3139 - map_output_accuracy: 0.9862 - map_output_map_loss: 0.0386
# Epoch 128/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 396ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2759 - adlo_output_loc_error: 0.0410 - adlo_output_orientation_error: 0.0558 - loss: 0.3151 - map_output_accuracy: 0.9860 - map_output_map_loss: 0.0392
# Epoch 129/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 396ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2730 - adlo_output_loc_error: 0.0388 - adlo_output_orientation_error: 0.0625 - loss: 0.3107 - map_output_accuracy: 0.9865 - map_output_map_loss: 0.0378
# Epoch 130/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 396ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2743 - adlo_output_loc_error: 0.0408 - adlo_output_orientation_error: 0.0636 - loss: 0.3125 - map_output_accuracy: 0.9863 - map_output_map_loss: 0.0383
# Epoch 131/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 391ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2756 - adlo_output_loc_error: 0.0389 - adlo_output_orientation_error: 0.0535 - loss: 0.3152 - map_output_accuracy: 0.9859 - map_output_map_loss: 0.0395
# Epoch 132/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 393ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2742 - adlo_output_loc_error: 0.0403 - adlo_output_orientation_error: 0.0608 - loss: 0.3171 - map_output_accuracy: 0.9849 - map_output_map_loss: 0.0429
# Epoch 133/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 393ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2700 - adlo_output_loc_error: 0.0484 - adlo_output_orientation_error: 0.0948 - loss: 0.3587 - map_output_accuracy: 0.9714 - map_output_map_loss: 0.0888
# Epoch 134/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 393ms/step - adlo_output_accept_accuracy: 0.9807 - adlo_output_adlo_loss: 0.3099 - adlo_output_loc_error: 0.0553 - adlo_output_orientation_error: 0.1239 - loss: 0.5368 - map_output_accuracy: 0.9216 - map_output_map_loss: 0.2272
# Epoch 135/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 389ms/step - adlo_output_accept_accuracy: 0.8950 - adlo_output_adlo_loss: 0.4499 - adlo_output_loc_error: 0.0892 - adlo_output_orientation_error: 0.2809 - loss: 0.8575 - map_output_accuracy: 0.8473 - map_output_map_loss: 0.4078
# Epoch 136/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 389ms/step - adlo_output_accept_accuracy: 0.9340 - adlo_output_adlo_loss: 0.3853 - adlo_output_loc_error: 0.0830 - adlo_output_orientation_error: 0.2853 - loss: 0.7758 - map_output_accuracy: 0.8542 - map_output_map_loss: 0.3906
# Epoch 137/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 385ms/step - adlo_output_accept_accuracy: 0.9516 - adlo_output_adlo_loss: 0.3597 - adlo_output_loc_error: 0.0753 - adlo_output_orientation_error: 0.2498 - loss: 0.6732 - map_output_accuracy: 0.8798 - map_output_map_loss: 0.3134
# Epoch 138/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 388ms/step - adlo_output_accept_accuracy: 0.9954 - adlo_output_adlo_loss: 0.3012 - adlo_output_loc_error: 0.0794 - adlo_output_orientation_error: 0.2803 - loss: 0.5149 - map_output_accuracy: 0.9219 - map_output_map_loss: 0.2137
# Epoch 139/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 389ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2918 - adlo_output_loc_error: 0.0773 - adlo_output_orientation_error: 0.2505 - loss: 0.4717 - map_output_accuracy: 0.9356 - map_output_map_loss: 0.1799
# Epoch 140/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 385ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2859 - adlo_output_loc_error: 0.0715 - adlo_output_orientation_error: 0.2240 - loss: 0.4062 - map_output_accuracy: 0.9574 - map_output_map_loss: 0.1204
# Epoch 141/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 383ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2826 - adlo_output_loc_error: 0.0667 - adlo_output_orientation_error: 0.1754 - loss: 0.3919 - map_output_accuracy: 0.9619 - map_output_map_loss: 0.1093
# Epoch 142/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 385ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2779 - adlo_output_loc_error: 0.0647 - adlo_output_orientation_error: 0.1386 - loss: 0.3609 - map_output_accuracy: 0.9708 - map_output_map_loss: 0.0829
# Epoch 143/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 384ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2744 - adlo_output_loc_error: 0.0592 - adlo_output_orientation_error: 0.1172 - loss: 0.3457 - map_output_accuracy: 0.9747 - map_output_map_loss: 0.0713
# Epoch 144/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 384ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2754 - adlo_output_loc_error: 0.0550 - adlo_output_orientation_error: 0.0993 - loss: 0.3394 - map_output_accuracy: 0.9773 - map_output_map_loss: 0.0639
# Epoch 145/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 390ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2696 - adlo_output_loc_error: 0.0554 - adlo_output_orientation_error: 0.0949 - loss: 0.3279 - map_output_accuracy: 0.9793 - map_output_map_loss: 0.0583
# Epoch 146/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 397ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2799 - adlo_output_loc_error: 0.0450 - adlo_output_orientation_error: 0.0729 - loss: 0.3430 - map_output_accuracy: 0.9776 - map_output_map_loss: 0.0631
# Epoch 147/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 401ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2753 - adlo_output_loc_error: 0.0495 - adlo_output_orientation_error: 0.0849 - loss: 0.3308 - map_output_accuracy: 0.9803 - map_output_map_loss: 0.0555
# Epoch 148/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 397ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2797 - adlo_output_loc_error: 0.0446 - adlo_output_orientation_error: 0.0674 - loss: 0.3351 - map_output_accuracy: 0.9803 - map_output_map_loss: 0.0554
# Epoch 149/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 397ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2772 - adlo_output_loc_error: 0.0466 - adlo_output_orientation_error: 0.0739 - loss: 0.3295 - map_output_accuracy: 0.9814 - map_output_map_loss: 0.0523
# Epoch 150/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 393ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2751 - adlo_output_loc_error: 0.0443 - adlo_output_orientation_error: 0.0714 - loss: 0.3243 - map_output_accuracy: 0.9824 - map_output_map_loss: 0.0493
# Epoch 151/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 395ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2774 - adlo_output_loc_error: 0.0447 - adlo_output_orientation_error: 0.0687 - loss: 0.3256 - map_output_accuracy: 0.9827 - map_output_map_loss: 0.0482
# Epoch 152/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 403ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2742 - adlo_output_loc_error: 0.0437 - adlo_output_orientation_error: 0.0680 - loss: 0.3221 - map_output_accuracy: 0.9829 - map_output_map_loss: 0.0479
# Epoch 153/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 400ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2751 - adlo_output_loc_error: 0.0456 - adlo_output_orientation_error: 0.0702 - loss: 0.3206 - map_output_accuracy: 0.9836 - map_output_map_loss: 0.0456
# Epoch 154/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 397ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2756 - adlo_output_loc_error: 0.0437 - adlo_output_orientation_error: 0.0701 - loss: 0.3211 - map_output_accuracy: 0.9837 - map_output_map_loss: 0.0455
# Epoch 155/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 393ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2745 - adlo_output_loc_error: 0.0432 - adlo_output_orientation_error: 0.0635 - loss: 0.3194 - map_output_accuracy: 0.9839 - map_output_map_loss: 0.0451
# Epoch 156/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 393ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2758 - adlo_output_loc_error: 0.0446 - adlo_output_orientation_error: 0.0686 - loss: 0.3197 - map_output_accuracy: 0.9843 - map_output_map_loss: 0.0439
# Epoch 157/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 394ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2723 - adlo_output_loc_error: 0.0437 - adlo_output_orientation_error: 0.0637 - loss: 0.3134 - map_output_accuracy: 0.9852 - map_output_map_loss: 0.0411
# Epoch 158/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 396ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2769 - adlo_output_loc_error: 0.0415 - adlo_output_orientation_error: 0.0634 - loss: 0.3204 - map_output_accuracy: 0.9845 - map_output_map_loss: 0.0436
# Epoch 159/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 397ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2709 - adlo_output_loc_error: 0.0422 - adlo_output_orientation_error: 0.0570 - loss: 0.3117 - map_output_accuracy: 0.9855 - map_output_map_loss: 0.0408
# Epoch 160/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 397ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2751 - adlo_output_loc_error: 0.0421 - adlo_output_orientation_error: 0.0640 - loss: 0.3156 - map_output_accuracy: 0.9855 - map_output_map_loss: 0.0405
# Epoch 161/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 397ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2753 - adlo_output_loc_error: 0.0427 - adlo_output_orientation_error: 0.0565 - loss: 0.3192 - map_output_accuracy: 0.9845 - map_output_map_loss: 0.0439
# Epoch 162/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 392ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2772 - adlo_output_loc_error: 0.0414 - adlo_output_orientation_error: 0.0635 - loss: 0.3199 - map_output_accuracy: 0.9847 - map_output_map_loss: 0.0427
# Epoch 163/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 398ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2750 - adlo_output_loc_error: 0.0454 - adlo_output_orientation_error: 0.0652 - loss: 0.3135 - map_output_accuracy: 0.9862 - map_output_map_loss: 0.0385
# Epoch 164/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 401ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2739 - adlo_output_loc_error: 0.0409 - adlo_output_orientation_error: 0.0609 - loss: 0.3132 - map_output_accuracy: 0.9860 - map_output_map_loss: 0.0394
# Epoch 165/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 398ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2754 - adlo_output_loc_error: 0.0411 - adlo_output_orientation_error: 0.0584 - loss: 0.3143 - map_output_accuracy: 0.9861 - map_output_map_loss: 0.0389
# Epoch 166/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 395ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2768 - adlo_output_loc_error: 0.0399 - adlo_output_orientation_error: 0.0617 - loss: 0.3152 - map_output_accuracy: 0.9862 - map_output_map_loss: 0.0384
# Epoch 167/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 398ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2729 - adlo_output_loc_error: 0.0411 - adlo_output_orientation_error: 0.0595 - loss: 0.3088 - map_output_accuracy: 0.9871 - map_output_map_loss: 0.0359
# Epoch 168/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 395ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2772 - adlo_output_loc_error: 0.0403 - adlo_output_orientation_error: 0.0572 - loss: 0.3140 - map_output_accuracy: 0.9868 - map_output_map_loss: 0.0368
# Epoch 169/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 397ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2751 - adlo_output_loc_error: 0.0426 - adlo_output_orientation_error: 0.0576 - loss: 0.3111 - map_output_accuracy: 0.9871 - map_output_map_loss: 0.0361
# Epoch 170/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 401ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2732 - adlo_output_loc_error: 0.0392 - adlo_output_orientation_error: 0.0576 - loss: 0.3117 - map_output_accuracy: 0.9863 - map_output_map_loss: 0.0385
# Epoch 171/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 399ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2711 - adlo_output_loc_error: 0.0437 - adlo_output_orientation_error: 0.0593 - loss: 0.3082 - map_output_accuracy: 0.9867 - map_output_map_loss: 0.0372
# Epoch 172/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 397ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2771 - adlo_output_loc_error: 0.0393 - adlo_output_orientation_error: 0.0606 - loss: 0.3159 - map_output_accuracy: 0.9860 - map_output_map_loss: 0.0388
# Epoch 173/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 391ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2796 - adlo_output_loc_error: 0.0403 - adlo_output_orientation_error: 0.0647 - loss: 0.3180 - map_output_accuracy: 0.9863 - map_output_map_loss: 0.0384
# Epoch 174/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 397ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2743 - adlo_output_loc_error: 0.0381 - adlo_output_orientation_error: 0.0630 - loss: 0.3103 - map_output_accuracy: 0.9870 - map_output_map_loss: 0.0360
# Epoch 175/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 397ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2814 - adlo_output_loc_error: 0.0402 - adlo_output_orientation_error: 0.0585 - loss: 0.3183 - map_output_accuracy: 0.9868 - map_output_map_loss: 0.0369
# Epoch 176/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 399ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2742 - adlo_output_loc_error: 0.0437 - adlo_output_orientation_error: 0.0589 - loss: 0.3084 - map_output_accuracy: 0.9877 - map_output_map_loss: 0.0342
# Epoch 177/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 398ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2767 - adlo_output_loc_error: 0.0395 - adlo_output_orientation_error: 0.0642 - loss: 0.3114 - map_output_accuracy: 0.9875 - map_output_map_loss: 0.0347
# Epoch 178/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 394ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2739 - adlo_output_loc_error: 0.0412 - adlo_output_orientation_error: 0.0570 - loss: 0.3065 - map_output_accuracy: 0.9882 - map_output_map_loss: 0.0327
# Epoch 179/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 397ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2748 - adlo_output_loc_error: 0.0368 - adlo_output_orientation_error: 0.0543 - loss: 0.3095 - map_output_accuracy: 0.9876 - map_output_map_loss: 0.0347
# Epoch 180/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 396ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2779 - adlo_output_loc_error: 0.0423 - adlo_output_orientation_error: 0.0626 - loss: 0.3131 - map_output_accuracy: 0.9875 - map_output_map_loss: 0.0352
# Epoch 181/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 398ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2755 - adlo_output_loc_error: 0.0408 - adlo_output_orientation_error: 0.0570 - loss: 0.3104 - map_output_accuracy: 0.9874 - map_output_map_loss: 0.0350
# Epoch 182/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 398ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2721 - adlo_output_loc_error: 0.0428 - adlo_output_orientation_error: 0.0594 - loss: 0.3067 - map_output_accuracy: 0.9875 - map_output_map_loss: 0.0346
# Epoch 183/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 398ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2782 - adlo_output_loc_error: 0.0438 - adlo_output_orientation_error: 0.0714 - loss: 0.3277 - map_output_accuracy: 0.9828 - map_output_map_loss: 0.0495
# Epoch 184/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 397ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2748 - adlo_output_loc_error: 0.0422 - adlo_output_orientation_error: 0.0665 - loss: 0.3178 - map_output_accuracy: 0.9849 - map_output_map_loss: 0.0430
# Epoch 185/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 400ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2778 - adlo_output_loc_error: 0.0416 - adlo_output_orientation_error: 0.0677 - loss: 0.3196 - map_output_accuracy: 0.9852 - map_output_map_loss: 0.0419
# Epoch 186/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 398ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2753 - adlo_output_loc_error: 0.0433 - adlo_output_orientation_error: 0.0755 - loss: 0.3183 - map_output_accuracy: 0.9849 - map_output_map_loss: 0.0430
# Epoch 187/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 397ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2752 - adlo_output_loc_error: 0.0420 - adlo_output_orientation_error: 0.0714 - loss: 0.3213 - map_output_accuracy: 0.9841 - map_output_map_loss: 0.0462
# Epoch 188/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 392ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2762 - adlo_output_loc_error: 0.0420 - adlo_output_orientation_error: 0.0675 - loss: 0.3252 - map_output_accuracy: 0.9832 - map_output_map_loss: 0.0490
# Epoch 189/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 396ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2718 - adlo_output_loc_error: 0.0429 - adlo_output_orientation_error: 0.0661 - loss: 0.3172 - map_output_accuracy: 0.9841 - map_output_map_loss: 0.0454
# Epoch 190/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 398ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2741 - adlo_output_loc_error: 0.0433 - adlo_output_orientation_error: 0.0677 - loss: 0.3153 - map_output_accuracy: 0.9854 - map_output_map_loss: 0.0413
# Epoch 191/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 402ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2751 - adlo_output_loc_error: 0.0460 - adlo_output_orientation_error: 0.0711 - loss: 0.3201 - map_output_accuracy: 0.9843 - map_output_map_loss: 0.0449
# Epoch 192/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 400ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2746 - adlo_output_loc_error: 0.0432 - adlo_output_orientation_error: 0.0629 - loss: 0.3183 - map_output_accuracy: 0.9847 - map_output_map_loss: 0.0436
# Epoch 193/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 393ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2829 - adlo_output_loc_error: 0.0424 - adlo_output_orientation_error: 0.0778 - loss: 0.3544 - map_output_accuracy: 0.9761 - map_output_map_loss: 0.0715
# Epoch 194/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 396ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2781 - adlo_output_loc_error: 0.0398 - adlo_output_orientation_error: 0.0727 - loss: 0.3382 - map_output_accuracy: 0.9797 - map_output_map_loss: 0.0601
# Epoch 195/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 403ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2756 - adlo_output_loc_error: 0.0426 - adlo_output_orientation_error: 0.0766 - loss: 0.3301 - map_output_accuracy: 0.9813 - map_output_map_loss: 0.0545
# Epoch 196/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 397ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2764 - adlo_output_loc_error: 0.0460 - adlo_output_orientation_error: 0.0747 - loss: 0.3301 - map_output_accuracy: 0.9815 - map_output_map_loss: 0.0537
# Epoch 197/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 395ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2775 - adlo_output_loc_error: 0.0408 - adlo_output_orientation_error: 0.0799 - loss: 0.3247 - map_output_accuracy: 0.9836 - map_output_map_loss: 0.0473
# Epoch 198/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 397ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2769 - adlo_output_loc_error: 0.0422 - adlo_output_orientation_error: 0.0720 - loss: 0.3235 - map_output_accuracy: 0.9837 - map_output_map_loss: 0.0466
# Epoch 199/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 402ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2756 - adlo_output_loc_error: 0.0461 - adlo_output_orientation_error: 0.0662 - loss: 0.3178 - map_output_accuracy: 0.9853 - map_output_map_loss: 0.0422
# Epoch 200/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 395ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.2749 - adlo_output_loc_error: 0.0446 - adlo_output_orientation_error: 0.0640 - loss: 0.3169 - map_output_accuracy: 0.9852 - map_output_map_loss: 0.0420
# Epochs: 200, duration: 3365.9359133629996 sec
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# adlo:             [1. 0. 0. 0.]
# adlo-pred raw:    [ 1.7158768  -0.00886392  0.01309464 -0.00668597]
# adlo-pred scaled: [ 0.847597   -0.00443184  0.00654695 -0.00668587]
# adlo:             [0. 0. 0. 0.]
# adlo-pred raw:    [-1.3886049e+00  1.0221871e-03 -6.1468952e-03 -1.5333679e-04]
# adlo-pred scaled: [ 1.9963056e-01  5.1109330e-04 -3.0734087e-03 -1.5333679e-04]
# adlo:             [ 1.          0.33607876 -0.16260384  0.29634374]
# adlo-pred raw:    [ 1.6923771   0.37815905 -0.21679866  0.29573226]
# adlo-pred scaled: [ 0.8445365   0.18055382 -0.10673234  0.2874022 ]
# adlo:             [1. 0. 0. 0.]
# adlo-pred raw:    [ 1.7127297  -0.02087059  0.00623867  0.00722063]
# adlo-pred scaled: [ 0.84719    -0.01043378  0.0031193   0.0072205 ]
# adlo:             [1.         0.17887953 0.22063265 0.16403958]
# adlo-pred raw:    [1.725787   0.05792214 0.1726845  0.13799648]
# adlo-pred scaled: [0.8488727  0.02892872 0.08549412 0.13712713]

# %%
# save model to disk for getting back into this later
model.save('experimental-slam-model1-200epochs.keras')

# ...or relead
#unet = tf.keras.models.load_model('experimental-slam-model1-200epochs.keras')

# %% [markdown]
# ## Learnings
#
# * Training
#   * Training is now taking ~400ms/step. That's much slower than for the sample single-headed UNet and it means I have to wait a long time to get useful results.
#   * There may be some overhead with the extra metrics.
#   * Additionally, I'm having to repeat the scaling conversions against the ADLO output every time I use them, even when computing loss. So there's clearly no point in returning un-scaled values there.
# * Dataset
#   * There is much to be desired about this dataset. It's all or nothing input map without any noise leads to the network blindly copying it through and not adding anything. The number of environments (1) is also too low as the network is overtraining on this environment.
# * ADLO Accept
#   * All indications are that the loss function is correctly calculating the right value. I have to assume that it also translates into appropriate gradients. So I have to assume for now that the problem is just that the ADLO part of the network actually has a tough job and it'll need a lot more training to get there.
#   * In fact, it reaches 100% accuracy after about 25 epochs.
# * ADLO Delta Location
#   * This plateaus at a mean error of 4.5% of window size - which is a sizeable distance.
#   * The clear plateau in the ADLO loss seems to suggest that the network capacity is saturated. I need either a larger ADLO block, or a slightly different architecture.
# * ADLO Delta Orientation
#   * This plateaus at a mean error of 6.4% of pi = 11.5 degrees.
#   * This network is also saturated.
#
#
# Final epoch:
# ```
# loss: 0.3169
# map_output_map_loss: 0.0420
# adlo_output_adlo_loss: 0.2749
# map_output_accuracy: 0.9852
# adlo_output_accept_accuracy: 1.0000
# adlo_output_loc_error: 0.0446
# adlo_output_orientation_error: 0.0640
# ```
#
# Most of the other learnings from v1 are also applicable still...
#
# **Problems:**
# * ADLO accuracy is very low.
# * Input maps are too complete and too perfect. They're exactly the same as the ground-truth maps, so there's nothing for the NN to do, and no incentive to use the LDS data to improve the map.
# * The NN should always prefer the LDS data over its the input map, as the input map represents only a guess, while LDS is true state. I don't think I've got this balanced quite right in the training data yet.
#
# **Next steps for model:**
# * Improve data representation / loss functions so that it correctly ignores output components that aren't important for certain situations (eg: when expecting accept=false, don't care about delta location/orientation).
#
# **Next steps for training data:**
# * Simulate an agent actually moving around an environment and building up the map from parts, instead of the current extremes: being given either a fully-known map or no-map in between.
#   * Imagine taking a path along the map.
#   * At each location collect what it can see within the LDS range - this collects a circle of data.
#   * Then add some noise the LDS data before turning it into the input map.
#   * Later on optionally add motion-skew (where the agent continuously slowly slides slightly to one side so that the SLAM map ends up over a curve and the NN will have to correct that).
#   * API note: add collection of options for turning different kinds of errors on/off.
# * Play around with occlusions more. Instead of being given a full map for the current location it should be given only a partial map, forcing it to do a partial-match on the map and the LDS data. eg:
#   * Randomly drop half of the input map, centred on the map centre, according to a dividing line that goes through the centre at some random angle.
#   * Use ~1/3rd sized circles of LDS range and randomly splat them around the map filling in only the parts that are splatted. Do this to build up the input map that is then snapshotted. Take a random number of splats, to simulate different levels of known map. Could be easy to implement by first building up mask from the splats and then applying that against the full map.

# %% [markdown]
# ## Bug fix
# I'd made a mistake with the ADLO loss function, not actually using the scaled values for the DLO loss. So let's try that again and compare.

# %%
# Custom loss functions
# (out-of-the-box the two outputs get losses calculated independently,
#  ultimately I'll be wanting to conditionally choose whether the map loss
#  is considered depending on how the network is being used.
#  The easiest way to do that will be to generate the dataset so that the ground_truth_map
#  is blank for those cases)

def adlo_loss(y_true, y_pred):
    """
    y_true: (B,4), scaled
    y_pred: (B,4), logits
    """
    y_true = tf.cast(y_true, tf.float32)

    # binary cross-entropy loss for accept
    accept_true = y_true[:, 0]
    accept_pred = y_pred[:, 0]
    accept_losses = tf.keras.losses.binary_crossentropy(accept_true, accept_pred, from_logits=True)

    # log-cosh loss for delta x, y, orientation
    dlo_true = y_true[:, 1:4]
    delta_x = tf.math.tanh(y_pred[:, 1]) * 0.5  # -0.5 .. +0.5
    delta_y = tf.math.tanh(y_pred[:, 2]) * 0.5  # -0.5 .. +0.5
    delta_angle = tf.math.tanh(y_pred[:, 3])    # -1.0 .. +1.0
    dlo_pred = tf.stack([delta_x, delta_y, delta_angle], axis=1)
    dlo_losses = tf.reduce_mean(tf.math.log(tf.cosh(dlo_pred - dlo_true)))

    return accept_losses + dlo_losses

def accept_accuracy(y_true, y_pred):
    accept_true = tf.cast(y_true[:, 0], tf.float32)
    accept_pred = tf.cast(tf.round(tf.nn.sigmoid(y_pred[:, 0])), tf.float32)
    matches = tf.equal(accept_true, accept_pred)
    return tf.reduce_mean(tf.cast(matches, tf.float32))

def loc_error(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    loc_true = y_true[:, 1:3]
    loc_pred = tf.math.tanh(y_pred[:, 1:3]) * 0.5  # -0.5 .. +0.5
    losses = tf.math.sqrt(tf.keras.losses.MSE(loc_true, loc_pred))
    return tf.reduce_mean(losses)

def orientation_error(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    angle_true = y_true[:, 3]
    angle_pred = tf.math.tanh(y_pred[:, 3])  # -1.0 .. +1.0
    losses = tf.math.sqrt(tf.keras.losses.MSE(angle_true, angle_pred))
    return tf.reduce_mean(losses)

reload(slam)
reload(slam_data)
one = next(iter(train_data))
map_shape = one[0][0].shape
print(f"map_shape: {map_shape}")
np.random.seed(42)
tf.random.set_seed(42)

model = slam.slam_model(map_shape, conv_filters=32, adlo_units=256)
model.compile(optimizer='adam',
              #run_eagerly=True,
              loss={
                  'map_output': tf.keras.losses.CategoricalCrossentropy(from_logits=True),
                  'adlo_output': adlo_loss
              },
              metrics={
                  'map_output': [tf.keras.metrics.CategoricalCrossentropy(from_logits=True, name='map_loss'), 'accuracy'],
                  'adlo_output': [adlo_loss, accept_accuracy, loc_error, orientation_error]
              })

epochs = 100
batch_size = 32
model_train_data = train_data.shuffle(buffer_size=len(train_data)).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

start = timer()
model_history = model.fit(model_train_data, epochs=epochs)
duration = (timer() - start)
print(f"Epochs: {epochs}, duration: {duration} sec")
display_history(model_history)
slam_data.show_predictions(model, train_data, 5, show_classes='pred')
# Out:
# map_shape: (149, 149, 3)
# Added final cropping layer: w=11, h=11
# Prepared SLAM model
#   Map shape:        (149, 149, 3) + padding (11, 11, 0)
#   Skip-connections: concat
#   Output scaling:   logits
#   Inputs:           [<KerasTensor shape=(None, 149, 149, 3), dtype=float32, sparse=None, name=map_input>, <KerasTensor shape=(None, 149, 149), dtype=float32, sparse=None, name=lds_input>]
#   Outputs:          [<KerasTensor shape=(None, 149, 149, 3), dtype=float32, sparse=False, name=keras_tensor_165>, <KerasTensor shape=(None, 4), dtype=float32, sparse=False, name=keras_tensor_170>]
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 38s 607ms/step - adlo_output_accept_accuracy: 0.7114 - adlo_output_adlo_loss: 0.9626 - adlo_output_loc_error: 0.1909 - adlo_output_orientation_error: 0.4874 - loss: 1.7334 - map_output_accuracy: 0.6491 - map_output_map_loss: 0.7703
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 372ms/step - adlo_output_accept_accuracy: 0.7431 - adlo_output_adlo_loss: 0.5827 - adlo_output_loc_error: 0.1039 - adlo_output_orientation_error: 0.2880 - loss: 1.2111 - map_output_accuracy: 0.7418 - map_output_map_loss: 0.6285
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 376ms/step - adlo_output_accept_accuracy: 0.7344 - adlo_output_adlo_loss: 0.5363 - adlo_output_loc_error: 0.1021 - adlo_output_orientation_error: 0.2782 - loss: 1.1296 - map_output_accuracy: 0.7509 - map_output_map_loss: 0.5930
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 386ms/step - adlo_output_accept_accuracy: 0.7108 - adlo_output_adlo_loss: 0.5238 - adlo_output_loc_error: 0.0884 - adlo_output_orientation_error: 0.2724 - loss: 1.0805 - map_output_accuracy: 0.7717 - map_output_map_loss: 0.5567
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 384ms/step - adlo_output_accept_accuracy: 0.7142 - adlo_output_adlo_loss: 0.5243 - adlo_output_loc_error: 0.0819 - adlo_output_orientation_error: 0.2635 - loss: 1.0634 - map_output_accuracy: 0.7798 - map_output_map_loss: 0.5389
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 386ms/step - adlo_output_accept_accuracy: 0.7463 - adlo_output_adlo_loss: 0.5193 - adlo_output_loc_error: 0.1035 - adlo_output_orientation_error: 0.2908 - loss: 1.0291 - map_output_accuracy: 0.7947 - map_output_map_loss: 0.5095
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 391ms/step - adlo_output_accept_accuracy: 0.7387 - adlo_output_adlo_loss: 0.5058 - adlo_output_loc_error: 0.0825 - adlo_output_orientation_error: 0.2647 - loss: 1.0287 - map_output_accuracy: 0.7849 - map_output_map_loss: 0.5228
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 391ms/step - adlo_output_accept_accuracy: 0.7313 - adlo_output_adlo_loss: 0.5049 - adlo_output_loc_error: 0.0839 - adlo_output_orientation_error: 0.2653 - loss: 1.0376 - map_output_accuracy: 0.7759 - map_output_map_loss: 0.5328
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 394ms/step - adlo_output_accept_accuracy: 0.7558 - adlo_output_adlo_loss: 0.4910 - adlo_output_loc_error: 0.1020 - adlo_output_orientation_error: 0.2708 - loss: 0.9920 - map_output_accuracy: 0.8022 - map_output_map_loss: 0.5007
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 393ms/step - adlo_output_accept_accuracy: 0.7473 - adlo_output_adlo_loss: 0.4838 - adlo_output_loc_error: 0.0896 - adlo_output_orientation_error: 0.2885 - loss: 1.0129 - map_output_accuracy: 0.7832 - map_output_map_loss: 0.5289
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 391ms/step - adlo_output_accept_accuracy: 0.7894 - adlo_output_adlo_loss: 0.4620 - adlo_output_loc_error: 0.0839 - adlo_output_orientation_error: 0.2673 - loss: 0.9772 - map_output_accuracy: 0.7901 - map_output_map_loss: 0.5149
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 395ms/step - adlo_output_accept_accuracy: 0.7741 - adlo_output_adlo_loss: 0.4777 - adlo_output_loc_error: 0.0905 - adlo_output_orientation_error: 0.2704 - loss: 0.9797 - map_output_accuracy: 0.7985 - map_output_map_loss: 0.5020
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 393ms/step - adlo_output_accept_accuracy: 0.7666 - adlo_output_adlo_loss: 0.4617 - adlo_output_loc_error: 0.0843 - adlo_output_orientation_error: 0.2735 - loss: 0.9655 - map_output_accuracy: 0.7941 - map_output_map_loss: 0.5037
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 389ms/step - adlo_output_accept_accuracy: 0.7712 - adlo_output_adlo_loss: 0.4276 - adlo_output_loc_error: 0.0837 - adlo_output_orientation_error: 0.2586 - loss: 0.9336 - map_output_accuracy: 0.7894 - map_output_map_loss: 0.5062
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 390ms/step - adlo_output_accept_accuracy: 0.7671 - adlo_output_adlo_loss: 0.4226 - adlo_output_loc_error: 0.0893 - adlo_output_orientation_error: 0.2823 - loss: 0.9429 - map_output_accuracy: 0.7841 - map_output_map_loss: 0.5200
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 396ms/step - adlo_output_accept_accuracy: 0.7728 - adlo_output_adlo_loss: 0.4474 - adlo_output_loc_error: 0.0828 - adlo_output_orientation_error: 0.2491 - loss: 0.9451 - map_output_accuracy: 0.7958 - map_output_map_loss: 0.4982
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 397ms/step - adlo_output_accept_accuracy: 0.8072 - adlo_output_adlo_loss: 0.3799 - adlo_output_loc_error: 0.0961 - adlo_output_orientation_error: 0.2608 - loss: 0.8801 - map_output_accuracy: 0.7903 - map_output_map_loss: 0.5003
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 392ms/step - adlo_output_accept_accuracy: 0.8368 - adlo_output_adlo_loss: 0.3379 - adlo_output_loc_error: 0.0946 - adlo_output_orientation_error: 0.2628 - loss: 0.8168 - map_output_accuracy: 0.8002 - map_output_map_loss: 0.4790
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 385ms/step - adlo_output_accept_accuracy: 0.8273 - adlo_output_adlo_loss: 0.3590 - adlo_output_loc_error: 0.0975 - adlo_output_orientation_error: 0.2793 - loss: 0.8591 - map_output_accuracy: 0.7905 - map_output_map_loss: 0.4998
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 391ms/step - adlo_output_accept_accuracy: 0.8531 - adlo_output_adlo_loss: 0.3459 - adlo_output_loc_error: 0.1189 - adlo_output_orientation_error: 0.3087 - loss: 0.8407 - map_output_accuracy: 0.7910 - map_output_map_loss: 0.4949
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 392ms/step - adlo_output_accept_accuracy: 0.8652 - adlo_output_adlo_loss: 0.3238 - adlo_output_loc_error: 0.0998 - adlo_output_orientation_error: 0.2802 - loss: 0.8088 - map_output_accuracy: 0.7988 - map_output_map_loss: 0.4847
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 397ms/step - adlo_output_accept_accuracy: 0.8901 - adlo_output_adlo_loss: 0.2711 - adlo_output_loc_error: 0.1036 - adlo_output_orientation_error: 0.2909 - loss: 0.7530 - map_output_accuracy: 0.7975 - map_output_map_loss: 0.4817
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 394ms/step - adlo_output_accept_accuracy: 0.9234 - adlo_output_adlo_loss: 0.1990 - adlo_output_loc_error: 0.1045 - adlo_output_orientation_error: 0.2586 - loss: 0.6728 - map_output_accuracy: 0.8026 - map_output_map_loss: 0.4742
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 385ms/step - adlo_output_accept_accuracy: 0.9382 - adlo_output_adlo_loss: 0.1738 - adlo_output_loc_error: 0.1094 - adlo_output_orientation_error: 0.2794 - loss: 0.6549 - map_output_accuracy: 0.7959 - map_output_map_loss: 0.4812
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 391ms/step - adlo_output_accept_accuracy: 0.8959 - adlo_output_adlo_loss: 0.2384 - adlo_output_loc_error: 0.1105 - adlo_output_orientation_error: 0.2630 - loss: 0.7277 - map_output_accuracy: 0.7912 - map_output_map_loss: 0.4893
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 392ms/step - adlo_output_accept_accuracy: 0.9350 - adlo_output_adlo_loss: 0.1570 - adlo_output_loc_error: 0.1116 - adlo_output_orientation_error: 0.2709 - loss: 0.6159 - map_output_accuracy: 0.8093 - map_output_map_loss: 0.4589
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 396ms/step - adlo_output_accept_accuracy: 0.9464 - adlo_output_adlo_loss: 0.1396 - adlo_output_loc_error: 0.1173 - adlo_output_orientation_error: 0.2840 - loss: 0.6104 - map_output_accuracy: 0.8066 - map_output_map_loss: 0.4708
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 388ms/step - adlo_output_accept_accuracy: 0.9724 - adlo_output_adlo_loss: 0.1175 - adlo_output_loc_error: 0.1198 - adlo_output_orientation_error: 0.2804 - loss: 0.5969 - map_output_accuracy: 0.7956 - map_output_map_loss: 0.4792
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 391ms/step - adlo_output_accept_accuracy: 0.9620 - adlo_output_adlo_loss: 0.1359 - adlo_output_loc_error: 0.1084 - adlo_output_orientation_error: 0.2398 - loss: 0.5991 - map_output_accuracy: 0.8035 - map_output_map_loss: 0.4630
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 394ms/step - adlo_output_accept_accuracy: 0.9919 - adlo_output_adlo_loss: 0.0414 - adlo_output_loc_error: 0.1146 - adlo_output_orientation_error: 0.2551 - loss: 0.4971 - map_output_accuracy: 0.8096 - map_output_map_loss: 0.4556
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 390ms/step - adlo_output_accept_accuracy: 0.9836 - adlo_output_adlo_loss: 0.0613 - adlo_output_loc_error: 0.1088 - adlo_output_orientation_error: 0.2272 - loss: 0.5089 - map_output_accuracy: 0.8104 - map_output_map_loss: 0.4476
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 387ms/step - adlo_output_accept_accuracy: 0.9744 - adlo_output_adlo_loss: 0.0896 - adlo_output_loc_error: 0.1047 - adlo_output_orientation_error: 0.2483 - loss: 0.5307 - map_output_accuracy: 0.8155 - map_output_map_loss: 0.4410
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 392ms/step - adlo_output_accept_accuracy: 0.9663 - adlo_output_adlo_loss: 0.1110 - adlo_output_loc_error: 0.1005 - adlo_output_orientation_error: 0.2361 - loss: 0.5583 - map_output_accuracy: 0.8118 - map_output_map_loss: 0.4473
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 397ms/step - adlo_output_accept_accuracy: 0.9932 - adlo_output_adlo_loss: 0.0396 - adlo_output_loc_error: 0.1102 - adlo_output_orientation_error: 0.2314 - loss: 0.4821 - map_output_accuracy: 0.8108 - map_output_map_loss: 0.4425
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 388ms/step - adlo_output_accept_accuracy: 0.9922 - adlo_output_adlo_loss: 0.0355 - adlo_output_loc_error: 0.1011 - adlo_output_orientation_error: 0.2323 - loss: 0.4823 - map_output_accuracy: 0.8075 - map_output_map_loss: 0.4467
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 392ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0153 - adlo_output_loc_error: 0.0893 - adlo_output_orientation_error: 0.1943 - loss: 0.4444 - map_output_accuracy: 0.8167 - map_output_map_loss: 0.4291
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 388ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0084 - adlo_output_loc_error: 0.0847 - adlo_output_orientation_error: 0.1483 - loss: 0.4271 - map_output_accuracy: 0.8183 - map_output_map_loss: 0.4187
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 390ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0066 - adlo_output_loc_error: 0.0713 - adlo_output_orientation_error: 0.1390 - loss: 0.4291 - map_output_accuracy: 0.8133 - map_output_map_loss: 0.4225
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 393ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0059 - adlo_output_loc_error: 0.0719 - adlo_output_orientation_error: 0.1265 - loss: 0.4134 - map_output_accuracy: 0.8223 - map_output_map_loss: 0.4074
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 392ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0054 - adlo_output_loc_error: 0.0685 - adlo_output_orientation_error: 0.1195 - loss: 0.4026 - map_output_accuracy: 0.8273 - map_output_map_loss: 0.3972
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 394ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0052 - adlo_output_loc_error: 0.0627 - adlo_output_orientation_error: 0.1143 - loss: 0.3997 - map_output_accuracy: 0.8270 - map_output_map_loss: 0.3945
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 393ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0056 - adlo_output_loc_error: 0.0674 - adlo_output_orientation_error: 0.1205 - loss: 0.3964 - map_output_accuracy: 0.8276 - map_output_map_loss: 0.3908
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 390ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0043 - adlo_output_loc_error: 0.0568 - adlo_output_orientation_error: 0.1095 - loss: 0.3778 - map_output_accuracy: 0.8371 - map_output_map_loss: 0.3736
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 387ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0040 - adlo_output_loc_error: 0.0540 - adlo_output_orientation_error: 0.1050 - loss: 0.3858 - map_output_accuracy: 0.8349 - map_output_map_loss: 0.3818
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 391ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0040 - adlo_output_loc_error: 0.0551 - adlo_output_orientation_error: 0.1063 - loss: 0.3771 - map_output_accuracy: 0.8411 - map_output_map_loss: 0.3732
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 392ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0034 - adlo_output_loc_error: 0.0561 - adlo_output_orientation_error: 0.0933 - loss: 0.3687 - map_output_accuracy: 0.8424 - map_output_map_loss: 0.3653
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 393ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0035 - adlo_output_loc_error: 0.0518 - adlo_output_orientation_error: 0.0974 - loss: 0.3547 - map_output_accuracy: 0.8535 - map_output_map_loss: 0.3512
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 392ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0034 - adlo_output_loc_error: 0.0514 - adlo_output_orientation_error: 0.0946 - loss: 0.3444 - map_output_accuracy: 0.8561 - map_output_map_loss: 0.3410
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 395ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0033 - adlo_output_loc_error: 0.0503 - adlo_output_orientation_error: 0.0952 - loss: 0.3381 - map_output_accuracy: 0.8616 - map_output_map_loss: 0.3348
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 389ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0032 - adlo_output_loc_error: 0.0486 - adlo_output_orientation_error: 0.0936 - loss: 0.3130 - map_output_accuracy: 0.8747 - map_output_map_loss: 0.3099
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 393ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0042 - adlo_output_loc_error: 0.0504 - adlo_output_orientation_error: 0.1121 - loss: 0.3105 - map_output_accuracy: 0.8769 - map_output_map_loss: 0.3063
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 395ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0036 - adlo_output_loc_error: 0.0500 - adlo_output_orientation_error: 0.1059 - loss: 0.2881 - map_output_accuracy: 0.8887 - map_output_map_loss: 0.2845
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 388ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0033 - adlo_output_loc_error: 0.0492 - adlo_output_orientation_error: 0.0992 - loss: 0.2637 - map_output_accuracy: 0.9005 - map_output_map_loss: 0.2604
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 393ms/step - adlo_output_accept_accuracy: 0.9995 - adlo_output_adlo_loss: 0.0043 - adlo_output_loc_error: 0.0466 - adlo_output_orientation_error: 0.0973 - loss: 0.2655 - map_output_accuracy: 0.9012 - map_output_map_loss: 0.2612
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 396ms/step - adlo_output_accept_accuracy: 0.9981 - adlo_output_adlo_loss: 0.0148 - adlo_output_loc_error: 0.0652 - adlo_output_orientation_error: 0.1395 - loss: 0.3345 - map_output_accuracy: 0.8752 - map_output_map_loss: 0.3202
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 388ms/step - adlo_output_accept_accuracy: 0.9432 - adlo_output_adlo_loss: 0.1827 - adlo_output_loc_error: 0.0895 - adlo_output_orientation_error: 0.2129 - loss: 0.5846 - map_output_accuracy: 0.8338 - map_output_map_loss: 0.4017
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 392ms/step - adlo_output_accept_accuracy: 0.9033 - adlo_output_adlo_loss: 0.2779 - adlo_output_loc_error: 0.0989 - adlo_output_orientation_error: 0.2417 - loss: 0.7271 - map_output_accuracy: 0.8113 - map_output_map_loss: 0.4502
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 389ms/step - adlo_output_accept_accuracy: 0.8818 - adlo_output_adlo_loss: 0.3107 - adlo_output_loc_error: 0.0901 - adlo_output_orientation_error: 0.2581 - loss: 0.7596 - map_output_accuracy: 0.8071 - map_output_map_loss: 0.4487
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 395ms/step - adlo_output_accept_accuracy: 0.9902 - adlo_output_adlo_loss: 0.0461 - adlo_output_loc_error: 0.1037 - adlo_output_orientation_error: 0.2529 - loss: 0.4358 - map_output_accuracy: 0.8334 - map_output_map_loss: 0.3898
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 395ms/step - adlo_output_accept_accuracy: 0.9995 - adlo_output_adlo_loss: 0.0172 - adlo_output_loc_error: 0.0960 - adlo_output_orientation_error: 0.2048 - loss: 0.3846 - map_output_accuracy: 0.8472 - map_output_map_loss: 0.3674
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 391ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0098 - adlo_output_loc_error: 0.0786 - adlo_output_orientation_error: 0.1618 - loss: 0.3326 - map_output_accuracy: 0.8694 - map_output_map_loss: 0.3228
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 390ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0059 - adlo_output_loc_error: 0.0661 - adlo_output_orientation_error: 0.1254 - loss: 0.2949 - map_output_accuracy: 0.8866 - map_output_map_loss: 0.2889
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 390ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0057 - adlo_output_loc_error: 0.0662 - adlo_output_orientation_error: 0.1171 - loss: 0.2861 - map_output_accuracy: 0.8935 - map_output_map_loss: 0.2804
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 389ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0047 - adlo_output_loc_error: 0.0571 - adlo_output_orientation_error: 0.1139 - loss: 0.2731 - map_output_accuracy: 0.8966 - map_output_map_loss: 0.2683
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 392ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0041 - adlo_output_loc_error: 0.0547 - adlo_output_orientation_error: 0.0999 - loss: 0.2355 - map_output_accuracy: 0.9142 - map_output_map_loss: 0.2314
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 396ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0035 - adlo_output_loc_error: 0.0527 - adlo_output_orientation_error: 0.0981 - loss: 0.2110 - map_output_accuracy: 0.9242 - map_output_map_loss: 0.2075
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 393ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0035 - adlo_output_loc_error: 0.0508 - adlo_output_orientation_error: 0.0972 - loss: 0.1989 - map_output_accuracy: 0.9285 - map_output_map_loss: 0.1955
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 390ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0032 - adlo_output_loc_error: 0.0481 - adlo_output_orientation_error: 0.0950 - loss: 0.1811 - map_output_accuracy: 0.9375 - map_output_map_loss: 0.1780
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 396ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0035 - adlo_output_loc_error: 0.0532 - adlo_output_orientation_error: 0.0874 - loss: 0.1691 - map_output_accuracy: 0.9414 - map_output_map_loss: 0.1655
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 389ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0027 - adlo_output_loc_error: 0.0466 - adlo_output_orientation_error: 0.0877 - loss: 0.1630 - map_output_accuracy: 0.9437 - map_output_map_loss: 0.1603
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 391ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0027 - adlo_output_loc_error: 0.0449 - adlo_output_orientation_error: 0.0884 - loss: 0.1614 - map_output_accuracy: 0.9442 - map_output_map_loss: 0.1587
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 397ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0025 - adlo_output_loc_error: 0.0413 - adlo_output_orientation_error: 0.0860 - loss: 0.1544 - map_output_accuracy: 0.9467 - map_output_map_loss: 0.1519
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 397ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0025 - adlo_output_loc_error: 0.0440 - adlo_output_orientation_error: 0.0852 - loss: 0.1524 - map_output_accuracy: 0.9473 - map_output_map_loss: 0.1499
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 393ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0027 - adlo_output_loc_error: 0.0420 - adlo_output_orientation_error: 0.0796 - loss: 0.1565 - map_output_accuracy: 0.9454 - map_output_map_loss: 0.1538
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 386ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0024 - adlo_output_loc_error: 0.0418 - adlo_output_orientation_error: 0.0834 - loss: 0.1443 - map_output_accuracy: 0.9500 - map_output_map_loss: 0.1419
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 389ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0023 - adlo_output_loc_error: 0.0406 - adlo_output_orientation_error: 0.0806 - loss: 0.1371 - map_output_accuracy: 0.9525 - map_output_map_loss: 0.1348
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 396ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0023 - adlo_output_loc_error: 0.0418 - adlo_output_orientation_error: 0.0859 - loss: 0.1334 - map_output_accuracy: 0.9539 - map_output_map_loss: 0.1311
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 397ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0020 - adlo_output_loc_error: 0.0376 - adlo_output_orientation_error: 0.0784 - loss: 0.1295 - map_output_accuracy: 0.9547 - map_output_map_loss: 0.1276
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 394ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0018 - adlo_output_loc_error: 0.0350 - adlo_output_orientation_error: 0.0772 - loss: 0.1268 - map_output_accuracy: 0.9560 - map_output_map_loss: 0.1251
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 390ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0019 - adlo_output_loc_error: 0.0353 - adlo_output_orientation_error: 0.0746 - loss: 0.1314 - map_output_accuracy: 0.9548 - map_output_map_loss: 0.1295
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 389ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0017 - adlo_output_loc_error: 0.0370 - adlo_output_orientation_error: 0.0724 - loss: 0.1158 - map_output_accuracy: 0.9602 - map_output_map_loss: 0.1141
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 390ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0014 - adlo_output_loc_error: 0.0358 - adlo_output_orientation_error: 0.0628 - loss: 0.1123 - map_output_accuracy: 0.9611 - map_output_map_loss: 0.1109
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 390ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0018 - adlo_output_loc_error: 0.0363 - adlo_output_orientation_error: 0.0728 - loss: 0.1179 - map_output_accuracy: 0.9594 - map_output_map_loss: 0.1161
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 395ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0015 - adlo_output_loc_error: 0.0344 - adlo_output_orientation_error: 0.0677 - loss: 0.1099 - map_output_accuracy: 0.9618 - map_output_map_loss: 0.1084
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 394ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0015 - adlo_output_loc_error: 0.0337 - adlo_output_orientation_error: 0.0659 - loss: 0.1098 - map_output_accuracy: 0.9619 - map_output_map_loss: 0.1082
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 392ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0016 - adlo_output_loc_error: 0.0327 - adlo_output_orientation_error: 0.0715 - loss: 0.1061 - map_output_accuracy: 0.9629 - map_output_map_loss: 0.1046
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 396ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0013 - adlo_output_loc_error: 0.0339 - adlo_output_orientation_error: 0.0604 - loss: 0.1065 - map_output_accuracy: 0.9631 - map_output_map_loss: 0.1052
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 394ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0015 - adlo_output_loc_error: 0.0338 - adlo_output_orientation_error: 0.0659 - loss: 0.1041 - map_output_accuracy: 0.9635 - map_output_map_loss: 0.1027
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 388ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0018 - adlo_output_loc_error: 0.0338 - adlo_output_orientation_error: 0.0780 - loss: 0.1051 - map_output_accuracy: 0.9638 - map_output_map_loss: 0.1033
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 394ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0015 - adlo_output_loc_error: 0.0318 - adlo_output_orientation_error: 0.0642 - loss: 0.1106 - map_output_accuracy: 0.9620 - map_output_map_loss: 0.1091
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 393ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0011 - adlo_output_loc_error: 0.0296 - adlo_output_orientation_error: 0.0544 - loss: 0.1095 - map_output_accuracy: 0.9614 - map_output_map_loss: 0.1084
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 396ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0012 - adlo_output_loc_error: 0.0324 - adlo_output_orientation_error: 0.0572 - loss: 0.1007 - map_output_accuracy: 0.9646 - map_output_map_loss: 0.0995
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 396ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0012 - adlo_output_loc_error: 0.0299 - adlo_output_orientation_error: 0.0591 - loss: 0.0953 - map_output_accuracy: 0.9665 - map_output_map_loss: 0.0941
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 390ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0012 - adlo_output_loc_error: 0.0293 - adlo_output_orientation_error: 0.0610 - loss: 0.0963 - map_output_accuracy: 0.9664 - map_output_map_loss: 0.0951
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 390ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0010 - adlo_output_loc_error: 0.0294 - adlo_output_orientation_error: 0.0534 - loss: 0.0950 - map_output_accuracy: 0.9664 - map_output_map_loss: 0.0940
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 388ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0011 - adlo_output_loc_error: 0.0289 - adlo_output_orientation_error: 0.0567 - loss: 0.0875 - map_output_accuracy: 0.9692 - map_output_map_loss: 0.0864
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 391ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0011 - adlo_output_loc_error: 0.0305 - adlo_output_orientation_error: 0.0558 - loss: 0.0907 - map_output_accuracy: 0.9682 - map_output_map_loss: 0.0896
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 398ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0010 - adlo_output_loc_error: 0.0291 - adlo_output_orientation_error: 0.0566 - loss: 0.0828 - map_output_accuracy: 0.9708 - map_output_map_loss: 0.0818
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 392ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 9.2315e-04 - adlo_output_loc_error: 0.0281 - adlo_output_orientation_error: 0.0496 - loss: 0.0835 - map_output_accuracy: 0.9705 - map_output_map_loss: 0.0826
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 390ms/step - adlo_output_accept_accuracy: 1.0000 - adlo_output_adlo_loss: 0.0011 - adlo_output_loc_error: 0.0285 - adlo_output_orientation_error: 0.0568 - loss: 0.0838 - map_output_accuracy: 0.9702 - map_output_map_loss: 0.0827
# Epochs: 100, duration: 1646.0170584320003 sec
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# adlo:             [1. 0. 0. 0.]
# adlo-pred raw:    [13.330573    0.02228769 -0.04088859 -0.05612926]
# adlo-pred scaled: [ 0.99999833  0.011142   -0.02043291 -0.05607039]
# adlo:             [0. 0. 0. 0.]
# adlo-pred raw:    [-9.1681299e+00 -1.2566624e-03  2.3669528e-02  3.0496053e-02]
# adlo-pred scaled: [ 0.0001043  -0.00062833  0.01183255  0.0304866 ]
# adlo:             [ 1.          0.33607876 -0.16260384  0.29634374]
# adlo-pred raw:    [ 8.55104     0.619789   -0.32073426  0.27929944]
# adlo-pred scaled: [ 0.9998067   0.27549055 -0.15508534  0.27225655]
# adlo:             [1. 0. 0. 0.]
# adlo-pred raw:    [ 1.4381764e+01 -3.2851724e-03  1.6765865e-02 -4.7749326e-02]
# adlo-pred scaled: [ 0.9999994  -0.00164258  0.00838215 -0.04771306]
# adlo:             [1.         0.17887953 0.22063265 0.16403958]
# adlo-pred raw:    [11.046639    0.2228797   0.36013007  0.12133478]
# adlo-pred scaled: [0.999984   0.10963051 0.1726643  0.12074281]
