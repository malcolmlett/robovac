# %% [markdown]
# <a href="https://colab.research.google.com/github/malcolmlett/robovac/blob/main/Experiment_NN_LDS_to_OccupancyMap_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Experiment: NN prediction of Occupancy Map from LDS (v4)
# In this notebook I'll experiment with some minor architectural variations.

# %%
import os
if os.path.isdir('repo'):
  # discard any local changes and update
  # !cd repo && git reset --hard HEAD
  # !cd repo && git fetch
else:
  # !git clone https://github.com/malcolmlett/robovac.git repo

# lock to revision
# !cd repo && git checkout 12651a902e4451cadb29e750273d956a7d23f0a0
#!cd repo && git pull

import sys
sys.path.append('repo')

import lds
import map_from_lds_train_data
import unet
from importlib import reload
reload(lds)
reload(map_from_lds_train_data)
reload(unet)
# Out:
# HEAD is now at 15e7230 Adding ability to experiment with different conv kernel sizes
# Already up to date.
# <module 'unet' from '/content/repo/unet.py'>

# %%
# !pip install -Uqq ipdb

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
import io
import cv2
import requests
import math
import ipdb
from timeit import default_timer as timer

# %%
floorplan = Image.open('repo/data/experimental-floorplan1.png')
floorplan = np.array(floorplan, dtype=bool)
print(f"floorplan: shape={floorplan.shape}, dtype={floorplan.dtype}")
# Out:
# floorplan: shape=(84, 94), dtype=bool

# %% [markdown]
# ## Helper functions

# %%
def display_history(history):
  plt.figure(figsize=(11,3))
  plt.subplot(1,2,1)
  plt.plot(model_history.history["loss"])
  plt.title("Loss")

  plt.subplot(1,2,2)
  plt.plot(model_history.history["accuracy"])
  plt.title("Accuracy")
  plt.show()

def show_prediction(display_list, titles):
    plt.figure(figsize=(10, 3))

    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(titles[i])
        plt.imshow(display_list[i], cmap='gray')
        plt.axis('off')
    plt.show()

def show_predictions(model, dataset, num=1, show_probs=True):
    """
    Displays the first image of each of the num batches
    """
    for image, ground_truth in dataset.take(num):
        batch = np.expand_dims(image, axis=0)
        batch_pred = model.predict(batch)
        pred = tf.argmax(batch_pred, axis=-1)[0]

        if show_probs:
          # showing full details
          print(f"Class 0 logit range - {tf.reduce_min(batch_pred[..., 0])}, {tf.reduce_max(batch_pred[..., 0])}")
          print(f"Class 1 logit range - {tf.reduce_min(batch_pred[..., 1])}, {tf.reduce_max(batch_pred[..., 1])}")
          #probs = tf.nn.softmax(batch_pred[0], axis=-1)
          probs = batch_pred[0]  # show the raw logits
          class0_prob = probs[:, :, 0]
          class1_prob = probs[:, :, 1]
          show_prediction(
              [image, ground_truth, pred, class0_prob, class1_prob],
              ['LDS Data', 'Ground Truth', 'Predicted', 'Class 0', 'Class 1'])
        else:
          show_prediction([image, ground_truth, pred], ['LDS Data', 'Ground Truth', 'Predicted'])

# %% [markdown]
# ## Training data
# Just fetch the pre-generated training data.

# %%
# If generated data is available then load that to save time:
loaded = np.load('repo/data/experimental-lds-training-data1.npz')
X = loaded['X']
Y = loaded['Y']
print(f"X: {len(X)} x {X[0].shape}")
print(f"Y: {len(Y)} x {Y[0].shape}")

# Make available for training
dataset = tf.data.Dataset.from_tensor_slices((X, Y))
# Out:
# X: 1000 x (105, 105)
# Y: 1000 x (105, 105)

# %% [markdown]
# # Baseline
# Setup our simple model.
# And then let's get a sample result for a baseline.

# %%
data_shape = next(iter(dataset))[0].shape
input_size = (data_shape[0], data_shape[1], 1)
n_filters=32
n_classes=2

model = unet.unet_model(input_size, n_filters, n_classes)
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
epochs = 20
batch_size = 32
train_dataset = dataset.shuffle(buffer_size=len(X)).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

start = timer()
model_history = model.fit(train_dataset, epochs=epochs)
duration = (timer() - start)
print(f"Epochs: {epochs}, duration: {duration} sec")
display_history(model_history)
show_predictions(model, dataset, 5)
# Out:
# Input size: (105, 105, 1)
# Added padding layer: w=7, h=7
# Skip-connection merge mode: concat
# Output: logits
# Added final cropping layer: w=7, h=7
# Epoch 1/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 49s 675ms/step - accuracy: 0.8928 - ce: 0.9312 - loss: 0.9312
# Epoch 2/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 43s 134ms/step - accuracy: 0.9764 - ce: 0.1002 - loss: 0.1002
# Epoch 3/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9771 - ce: 0.0874 - loss: 0.0874
# Epoch 4/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9765 - ce: 0.0876 - loss: 0.0876
# Epoch 5/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 138ms/step - accuracy: 0.9768 - ce: 0.0856 - loss: 0.0856
# Epoch 6/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.9766 - ce: 0.0844 - loss: 0.0844
# Epoch 7/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 141ms/step - accuracy: 0.9766 - ce: 0.0835 - loss: 0.0835
# Epoch 8/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 141ms/step - accuracy: 0.9763 - ce: 0.0826 - loss: 0.0826
# Epoch 9/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 139ms/step - accuracy: 0.9766 - ce: 0.0807 - loss: 0.0807
# Epoch 10/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 141ms/step - accuracy: 0.9767 - ce: 0.0792 - loss: 0.0792
# Epoch 11/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9765 - ce: 0.0783 - loss: 0.0783
# Epoch 12/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9778 - ce: 0.0734 - loss: 0.0734
# Epoch 13/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9782 - ce: 0.0712 - loss: 0.0712
# Epoch 14/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 135ms/step - accuracy: 0.9788 - ce: 0.0688 - loss: 0.0688
# Epoch 15/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9788 - ce: 0.0683 - loss: 0.0683
# Epoch 16/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9796 - ce: 0.0632 - loss: 0.0632
# Epoch 17/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9797 - ce: 0.0608 - loss: 0.0608
# Epoch 18/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9798 - ce: 0.0594 - loss: 0.0594
# Epoch 19/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 135ms/step - accuracy: 0.9804 - ce: 0.0571 - loss: 0.0571
# Epoch 20/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9806 - ce: 0.0567 - loss: 0.0567
# Epochs: 20, duration: 179.27318462300002 sec

# %%
display_history(model_history)
show_predictions(model, dataset, 5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Class 0 logit range - -3.353217840194702, 11.550232887268066
# Class 1 logit range - -8.802824974060059, 2.7297935485839844
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Class 0 logit range - -5.750606536865234, 11.489163398742676
# Class 1 logit range - -9.048285484313965, 3.6793906688690186
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Class 0 logit range - -1.4214345216751099, 16.012399673461914
# Class 1 logit range - -12.610658645629883, 1.158756971359253
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Class 0 logit range - -1.2806317806243896, 14.04300308227539
# Class 1 logit range - -9.665277481079102, 0.9207220673561096
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Class 0 logit range - -1.1809577941894531, 16.52326011657715
# Class 1 logit range - -12.37106704711914, 0.7482752203941345

# %% [markdown]
# ## Kernel Size
# Let's see what ahppens with a larger kernel size.

# %%
data_shape = next(iter(dataset))[0].shape
input_size = (data_shape[0], data_shape[1], 1)
n_filters=32
n_classes=2

model = unet.unet_model(input_size, n_filters, n_classes, kernel_size=(5, 5))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
epochs = 20
batch_size = 32
train_dataset = dataset.shuffle(buffer_size=len(X)).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

start = timer()
model_history = model.fit(train_dataset, epochs=epochs)
duration = (timer() - start)
print(f"Epochs: {epochs}, duration: {duration} sec")
display_history(model_history)
show_predictions(model, dataset, 5)
# Out:
# Input size: (105, 105, 1)
# Added padding layer: w=7, h=7
# Skip-connection merge mode: concat
# Output: logits
# Added final cropping layer: w=7, h=7
# Epoch 1/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 57s 713ms/step - accuracy: 0.9604 - ce: 23.1523 - loss: 23.1523
# Epoch 2/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 263ms/step - accuracy: 0.9768 - ce: 0.1019 - loss: 0.1019
# Epoch 3/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 265ms/step - accuracy: 0.9761 - ce: 0.0913 - loss: 0.0913
# Epoch 4/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 266ms/step - accuracy: 0.9764 - ce: 0.0866 - loss: 0.0866
# Epoch 5/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 265ms/step - accuracy: 0.9771 - ce: 0.0835 - loss: 0.0835
# Epoch 6/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 272ms/step - accuracy: 0.9765 - ce: 0.0837 - loss: 0.0837
# Epoch 7/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 267ms/step - accuracy: 0.9768 - ce: 0.0818 - loss: 0.0818
# Epoch 8/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 270ms/step - accuracy: 0.9767 - ce: 0.0811 - loss: 0.0811
# Epoch 9/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 268ms/step - accuracy: 0.9766 - ce: 0.0797 - loss: 0.0797
# Epoch 10/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 268ms/step - accuracy: 0.9766 - ce: 0.0782 - loss: 0.0782
# Epoch 11/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 266ms/step - accuracy: 0.9772 - ce: 0.0765 - loss: 0.0765
# Epoch 12/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 266ms/step - accuracy: 0.9776 - ce: 0.0734 - loss: 0.0734
# Epoch 13/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 266ms/step - accuracy: 0.9780 - ce: 0.0715 - loss: 0.0715
# Epoch 14/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 268ms/step - accuracy: 0.9777 - ce: 0.0714 - loss: 0.0714
# Epoch 15/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 266ms/step - accuracy: 0.9774 - ce: 0.0750 - loss: 0.0750
# Epoch 16/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 268ms/step - accuracy: 0.9782 - ce: 0.0689 - loss: 0.0689
# Epoch 17/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 267ms/step - accuracy: 0.9785 - ce: 0.0675 - loss: 0.0675
# Epoch 18/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 269ms/step - accuracy: 0.9787 - ce: 0.0672 - loss: 0.0672
# Epoch 19/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 267ms/step - accuracy: 0.9792 - ce: 0.0643 - loss: 0.0643
# Epoch 20/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 266ms/step - accuracy: 0.9792 - ce: 0.0634 - loss: 0.0634
# Epochs: 20, duration: 237.36029327300002 sec
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Class 0 logit range - -2.0327394008636475, 22.99213218688965
# Class 1 logit range - -17.95277976989746, 3.165205240249634
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Class 0 logit range - -2.4755146503448486, 39.495418548583984
# Class 1 logit range - -31.6082763671875, 3.8812334537506104
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Class 0 logit range - -0.9101123213768005, 13.78393268585205
# Class 1 logit range - -10.75709056854248, 1.0705721378326416
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Class 0 logit range - -0.7810956239700317, 22.607959747314453
# Class 1 logit range - -18.178686141967773, 1.0823298692703247
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Class 0 logit range - -0.6198039054870605, 15.334480285644531
# Class 1 logit range - -12.010468482971191, 0.8209843039512634

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2             │ (None, 105, 105, 1)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ zero_padding2d_2          │ (None, 112, 112, 1)    │              0 │ input_layer_2[0][0]    │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_21 (Conv2D)        │ (None, 112, 112, 32)   │            832 │ zero_padding2d_2[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_22 (Conv2D)        │ (None, 112, 112, 32)   │         25,632 │ conv2d_21[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_4           │ (None, 56, 56, 32)     │              0 │ conv2d_22[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_23 (Conv2D)        │ (None, 56, 56, 64)     │         51,264 │ max_pooling2d_4[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_24 (Conv2D)        │ (None, 56, 56, 64)     │        102,464 │ conv2d_23[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_5           │ (None, 28, 28, 64)     │              0 │ conv2d_24[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_25 (Conv2D)        │ (None, 28, 28, 128)    │        204,928 │ max_pooling2d_5[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_26 (Conv2D)        │ (None, 28, 28, 128)    │        409,728 │ conv2d_25[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_6           │ (None, 14, 14, 128)    │              0 │ conv2d_26[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_27 (Conv2D)        │ (None, 14, 14, 256)    │        819,456 │ max_pooling2d_6[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_28 (Conv2D)        │ (None, 14, 14, 256)    │      1,638,656 │ conv2d_27[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 14, 14, 256)    │              0 │ conv2d_28[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_7           │ (None, 7, 7, 256)      │              0 │ dropout_2[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_29 (Conv2D)        │ (None, 7, 7, 512)      │      3,277,312 │ max_pooling2d_7[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_30 (Conv2D)        │ (None, 7, 7, 512)      │      6,554,112 │ conv2d_29[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 7, 7, 512)      │              0 │ conv2d_30[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_4        │ (None, 14, 14, 256)    │      3,277,056 │ dropout_3[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_4             │ (None, 14, 14, 512)    │              0 │ conv2d_transpose_4[0]… │
# │ (Concatenate)             │                        │                │ dropout_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_31 (Conv2D)        │ (None, 14, 14, 256)    │      3,277,056 │ concatenate_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_32 (Conv2D)        │ (None, 14, 14, 256)    │      1,638,656 │ conv2d_31[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_5        │ (None, 28, 28, 128)    │        819,328 │ conv2d_32[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_5             │ (None, 28, 28, 256)    │              0 │ conv2d_transpose_5[0]… │
# │ (Concatenate)             │                        │                │ conv2d_26[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_33 (Conv2D)        │ (None, 28, 28, 128)    │        819,328 │ concatenate_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_34 (Conv2D)        │ (None, 28, 28, 128)    │        409,728 │ conv2d_33[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_6        │ (None, 56, 56, 64)     │        204,864 │ conv2d_34[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_6             │ (None, 56, 56, 128)    │              0 │ conv2d_transpose_6[0]… │
# │ (Concatenate)             │                        │                │ conv2d_24[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_35 (Conv2D)        │ (None, 56, 56, 64)     │        204,864 │ concatenate_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_36 (Conv2D)        │ (None, 56, 56, 64)     │        102,464 │ conv2d_35[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_7        │ (None, 112, 112, 32)   │         51,232 │ conv2d_36[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_7             │ (None, 112, 112, 64)   │              0 │ conv2d_transpose_7[0]… │
# │ (Concatenate)             │                        │                │ conv2d_22[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_37 (Conv2D)        │ (None, 112, 112, 32)   │         51,232 │ concatenate_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_38 (Conv2D)        │ (None, 112, 112, 32)   │         25,632 │ conv2d_37[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_39 (Conv2D)        │ (None, 112, 112, 32)   │         25,632 │ conv2d_38[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_40 (Conv2D)        │ (None, 112, 112, 2)    │             66 │ conv2d_39[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ cropping2d_1 (Cropping2D) │ (None, 105, 105, 2)    │              0 │ conv2d_40[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 71,974,568 (274.56 MB)
#  Trainable params: 23,991,522 (91.52 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 47,983,046 (183.04 MB)

# %% [markdown]
# ## Results
# * 3x3 conv kernel (baseline):
#   * Total params: 25,917,608 (98.87 MB)
#   * Trainable params: 8,639,202 (32.96 MB)
#   * Optimizer params: 17,278,406 (65.91 MB)
#   * Training speed: 136ms/step (batch size 32, padding done as layer)
#   * After 20 epochs: accuracy = 0.9806, cross-entropy loss = 0.0567
# * 5x5 conv kernel:
#   * Total params: 71,974,568 (274.56 MB)
#   * Trainable params: 23,991,522 (91.52 MB)
#   * Optimizer params: 47,983,046 (183.04 MB)
#   * Training speed: 266ms/step
#   * After 20 epochs: accuracy = 0.9792, cross-entropy loss = 0.0634
#   * Visually much worse.
#   * Noticeably slower.
#
#   Conclusions:
#   * For the sake of experimentation efficiency, until I run into a problem of the training data getting too complex and the network getting saturated, this kernel size and most probably this depth too are perfectly sufficient for the task.

# %% [markdown]
# ## Long training against Baseline
# Let's run the baseline architecture for 200 epochs and see what result we get. This will be useful for comparing to later.

# %%
data_shape = next(iter(dataset))[0].shape
input_size = (data_shape[0], data_shape[1], 1)
model = unet.unet_model(input_size, n_filters=32, n_classes=2)
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])
train_dataset = dataset.shuffle(buffer_size=len(X)).batch(batch_size=32).prefetch(tf.data.experimental.AUTOTUNE)

start = timer()
model_history = model.fit(train_dataset, epochs=200)
duration = (timer() - start)
print(f"Epochs: {epochs}, duration: {duration} sec")
display_history(model_history)
show_predictions(model, dataset, 5)
# Out:
# Input size: (105, 105, 1)
# Added padding layer: w=7, h=7
# Skip-connection merge mode: concat
# Output: logits
# Added final cropping layer: w=7, h=7
# Epoch 1/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 332ms/step - accuracy: 0.9093 - loss: 0.6381
# Epoch 2/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - accuracy: 0.9760 - loss: 0.0963
# Epoch 3/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9768 - loss: 0.0880
# Epoch 4/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9767 - loss: 0.0868
# Epoch 5/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.9771 - loss: 0.0830
# Epoch 6/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 139ms/step - accuracy: 0.9767 - loss: 0.0835
# Epoch 7/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9767 - loss: 0.0827
# Epoch 8/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 135ms/step - accuracy: 0.9766 - loss: 0.0810
# Epoch 9/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9769 - loss: 0.0811
# Epoch 10/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9770 - loss: 0.0781
# Epoch 11/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - accuracy: 0.9777 - loss: 0.0736
# Epoch 12/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - accuracy: 0.9783 - loss: 0.0717
# Epoch 13/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9787 - loss: 0.0680
# Epoch 14/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 134ms/step - accuracy: 0.9790 - loss: 0.0658
# Epoch 15/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - accuracy: 0.9788 - loss: 0.0646
# Epoch 16/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 135ms/step - accuracy: 0.9795 - loss: 0.0626
# Epoch 17/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9789 - loss: 0.0633
# Epoch 18/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9800 - loss: 0.0591
# Epoch 19/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 135ms/step - accuracy: 0.9802 - loss: 0.0577
# Epoch 20/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9803 - loss: 0.0568
# Epoch 21/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9803 - loss: 0.0557
# Epoch 22/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9812 - loss: 0.0524
# Epoch 23/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.9812 - loss: 0.0529
# Epoch 24/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9818 - loss: 0.0512
# Epoch 25/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9820 - loss: 0.0495
# Epoch 26/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9823 - loss: 0.0482
# Epoch 27/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9829 - loss: 0.0460
# Epoch 28/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9830 - loss: 0.0451
# Epoch 29/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9834 - loss: 0.0435
# Epoch 30/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9832 - loss: 0.0438
# Epoch 31/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9837 - loss: 0.0425
# Epoch 32/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9841 - loss: 0.0401
# Epoch 33/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9839 - loss: 0.0407
# Epoch 34/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9843 - loss: 0.0394
# Epoch 35/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9849 - loss: 0.0375
# Epoch 36/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9852 - loss: 0.0368
# Epoch 37/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9854 - loss: 0.0362
# Epoch 38/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9857 - loss: 0.0355
# Epoch 39/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9857 - loss: 0.0352
# Epoch 40/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9863 - loss: 0.0333
# Epoch 41/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9864 - loss: 0.0328
# Epoch 42/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 138ms/step - accuracy: 0.9864 - loss: 0.0325
# Epoch 43/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9874 - loss: 0.0301
# Epoch 44/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9872 - loss: 0.0307
# Epoch 45/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9875 - loss: 0.0298
# Epoch 46/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9880 - loss: 0.0285
# Epoch 47/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9881 - loss: 0.0282
# Epoch 48/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9882 - loss: 0.0276
# Epoch 49/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9884 - loss: 0.0272
# Epoch 50/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.9884 - loss: 0.0271
# Epoch 51/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9885 - loss: 0.0270
# Epoch 52/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9886 - loss: 0.0266
# Epoch 53/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9889 - loss: 0.0258
# Epoch 54/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9889 - loss: 0.0259
# Epoch 55/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9893 - loss: 0.0249
# Epoch 56/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9897 - loss: 0.0239
# Epoch 57/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 135ms/step - accuracy: 0.9900 - loss: 0.0232
# Epoch 58/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9899 - loss: 0.0233
# Epoch 59/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 135ms/step - accuracy: 0.9902 - loss: 0.0226
# Epoch 60/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9904 - loss: 0.0219
# Epoch 61/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9905 - loss: 0.0221
# Epoch 62/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 135ms/step - accuracy: 0.9903 - loss: 0.0222
# Epoch 63/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9910 - loss: 0.0207
# Epoch 64/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9910 - loss: 0.0206
# Epoch 65/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9911 - loss: 0.0203
# Epoch 66/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9913 - loss: 0.0198
# Epoch 67/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9917 - loss: 0.0192
# Epoch 68/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9914 - loss: 0.0196
# Epoch 69/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9917 - loss: 0.0189
# Epoch 70/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9918 - loss: 0.0189
# Epoch 71/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9916 - loss: 0.0193
# Epoch 72/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9919 - loss: 0.0186
# Epoch 73/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9922 - loss: 0.0180
# Epoch 74/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9922 - loss: 0.0180
# Epoch 75/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9919 - loss: 0.0187
# Epoch 76/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9921 - loss: 0.0181
# Epoch 77/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9926 - loss: 0.0171
# Epoch 78/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9928 - loss: 0.0167
# Epoch 79/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9928 - loss: 0.0165
# Epoch 80/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9928 - loss: 0.0168
# Epoch 81/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9929 - loss: 0.0165
# Epoch 82/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9932 - loss: 0.0156
# Epoch 83/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9930 - loss: 0.0161
# Epoch 84/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9929 - loss: 0.0163
# Epoch 85/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 138ms/step - accuracy: 0.9934 - loss: 0.0155
# Epoch 86/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9934 - loss: 0.0151
# Epoch 87/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9938 - loss: 0.0144
# Epoch 88/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9937 - loss: 0.0146
# Epoch 89/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9937 - loss: 0.0147
# Epoch 90/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9937 - loss: 0.0145
# Epoch 91/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9937 - loss: 0.0147
# Epoch 92/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9939 - loss: 0.0142
# Epoch 93/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9940 - loss: 0.0140
# Epoch 94/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9935 - loss: 0.0150
# Epoch 95/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9940 - loss: 0.0139
# Epoch 96/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9940 - loss: 0.0140
# Epoch 97/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9939 - loss: 0.0143
# Epoch 98/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9942 - loss: 0.0136
# Epoch 99/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9944 - loss: 0.0131
# Epoch 100/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9943 - loss: 0.0133
# Epoch 101/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9945 - loss: 0.0130
# Epoch 102/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9942 - loss: 0.0135
# Epoch 103/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9947 - loss: 0.0126
# Epoch 104/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9947 - loss: 0.0123
# Epoch 105/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9945 - loss: 0.0129
# Epoch 106/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9950 - loss: 0.0120
# Epoch 107/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9950 - loss: 0.0119
# Epoch 108/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9952 - loss: 0.0114
# Epoch 109/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9952 - loss: 0.0114
# Epoch 110/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9953 - loss: 0.0112
# Epoch 111/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9953 - loss: 0.0111
# Epoch 112/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9954 - loss: 0.0108
# Epoch 113/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9955 - loss: 0.0107
# Epoch 114/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9953 - loss: 0.0113
# Epoch 115/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9953 - loss: 0.0113
# Epoch 116/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9953 - loss: 0.0112
# Epoch 117/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9950 - loss: 0.0122
# Epoch 118/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 135ms/step - accuracy: 0.9950 - loss: 0.0120
# Epoch 119/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9953 - loss: 0.0112
# Epoch 120/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9953 - loss: 0.0112
# Epoch 121/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9955 - loss: 0.0108
# Epoch 122/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9954 - loss: 0.0109
# Epoch 123/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9958 - loss: 0.0100
# Epoch 124/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9957 - loss: 0.0103
# Epoch 125/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9961 - loss: 0.0095
# Epoch 126/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9962 - loss: 0.0091
# Epoch 127/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9960 - loss: 0.0099
# Epoch 128/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9962 - loss: 0.0091
# Epoch 129/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9961 - loss: 0.0094
# Epoch 130/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9963 - loss: 0.0091
# Epoch 131/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9960 - loss: 0.0097
# Epoch 132/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9961 - loss: 0.0094
# Epoch 133/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9961 - loss: 0.0094
# Epoch 134/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9963 - loss: 0.0089
# Epoch 135/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9962 - loss: 0.0092
# Epoch 136/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 135ms/step - accuracy: 0.9958 - loss: 0.0102
# Epoch 137/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9961 - loss: 0.0094
# Epoch 138/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9962 - loss: 0.0093
# Epoch 139/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9962 - loss: 0.0092
# Epoch 140/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9962 - loss: 0.0093
# Epoch 141/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9966 - loss: 0.0083
# Epoch 142/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9968 - loss: 0.0077
# Epoch 143/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9967 - loss: 0.0080
# Epoch 144/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9968 - loss: 0.0078
# Epoch 145/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9968 - loss: 0.0078
# Epoch 146/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9968 - loss: 0.0079
# Epoch 147/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9970 - loss: 0.0075
# Epoch 148/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9971 - loss: 0.0072
# Epoch 149/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9967 - loss: 0.0081
# Epoch 150/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9940 - loss: 0.0149
# Epoch 151/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9948 - loss: 0.0126
# Epoch 152/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9960 - loss: 0.0098
# Epoch 153/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9965 - loss: 0.0086
# Epoch 154/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 135ms/step - accuracy: 0.9966 - loss: 0.0084
# Epoch 155/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9968 - loss: 0.0078
# Epoch 156/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 135ms/step - accuracy: 0.9969 - loss: 0.0077
# Epoch 157/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9969 - loss: 0.0077
# Epoch 158/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9970 - loss: 0.0074
# Epoch 159/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9972 - loss: 0.0070
# Epoch 160/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9973 - loss: 0.0067
# Epoch 161/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9973 - loss: 0.0068
# Epoch 162/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9967 - loss: 0.0083
# Epoch 163/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9973 - loss: 0.0067
# Epoch 164/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9972 - loss: 0.0070
# Epoch 165/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9974 - loss: 0.0065
# Epoch 166/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9976 - loss: 0.0063
# Epoch 167/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9976 - loss: 0.0061
# Epoch 168/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9977 - loss: 0.0059
# Epoch 169/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9976 - loss: 0.0061
# Epoch 170/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9978 - loss: 0.0057
# Epoch 171/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9978 - loss: 0.0056
# Epoch 172/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9978 - loss: 0.0056
# Epoch 173/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9978 - loss: 0.0056
# Epoch 174/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9977 - loss: 0.0057
# Epoch 175/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9980 - loss: 0.0052
# Epoch 176/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9978 - loss: 0.0055
# Epoch 177/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9978 - loss: 0.0056
# Epoch 178/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9977 - loss: 0.0057
# Epoch 179/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9978 - loss: 0.0055
# Epoch 180/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9980 - loss: 0.0052
# Epoch 181/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9978 - loss: 0.0057
# Epoch 182/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9977 - loss: 0.0059
# Epoch 183/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9978 - loss: 0.0056
# Epoch 184/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9978 - loss: 0.0057
# Epoch 185/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9975 - loss: 0.0064
# Epoch 186/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9973 - loss: 0.0069
# Epoch 187/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9976 - loss: 0.0059
# Epoch 188/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9979 - loss: 0.0054
# Epoch 189/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9980 - loss: 0.0052
# Epoch 190/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 135ms/step - accuracy: 0.9980 - loss: 0.0050
# Epoch 191/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9981 - loss: 0.0049
# Epoch 192/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9982 - loss: 0.0047
# Epoch 193/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9979 - loss: 0.0055
# Epoch 194/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9980 - loss: 0.0052
# Epoch 195/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9981 - loss: 0.0048
# Epoch 196/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9982 - loss: 0.0046
# Epoch 197/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9983 - loss: 0.0044
# Epoch 198/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9973 - loss: 0.0071
# Epoch 199/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9977 - loss: 0.0060
# Epoch 200/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9979 - loss: 0.0055
# Epochs: 2, duration: 961.2190375840003 sec
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Class 0 logit range - -6.276638507843018, 71.2861557006836
# Class 1 logit range - -84.15645599365234, 43.06684875488281
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Class 0 logit range - -7.631663799285889, 72.60686492919922
# Class 1 logit range - -100.6620864868164, 55.158390045166016
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Class 0 logit range - -3.4997360706329346, 55.7559700012207
# Class 1 logit range - -73.49876403808594, 26.580535888671875
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Class 0 logit range - -2.818577289581299, 51.53985595703125
# Class 1 logit range - -69.06954193115234, 21.01592254638672
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Class 0 logit range - -3.1484737396240234, 44.72184371948242
# Class 1 logit range - -55.097652435302734, 22.65713882446289
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-a9a37ccc8b67> in <cell line: 15>()
#      13
#      14 # save model before the runtime stops
# ---> 15 unet.save('unet200.keras')
#
# AttributeError: module 'unet' has no attribute 'save'

# %%
# save model to disk for getting back into this later
model.save('experimental-lds-to-occupancy-model1-200epochs.keras')

# ...or relead
#unet = tf.keras.models.load_model('unet.keras')
